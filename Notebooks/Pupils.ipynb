# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Pupillometry data

# %% [markdown]
# ### Paths

# %%
pup_paths = {}

pup_paths['P1T1'] = '../Pupillometry/Filtered/P1-task1.txt'
pup_paths['P1T2'] = '../Pupillometry/Filtered/P1-task2.txt'
pup_paths['P1T3'] = '../Pupillometry/Filtered/P1-task3.txt'
pup_paths['P1T4'] = '../Pupillometry/Filtered/P1-task4.txt'
pup_paths['P1T5'] = '../Pupillometry/Filtered/P1-task5.txt'
pup_paths['P1T6'] = '../Pupillometry/Filtered/P1-task6.txt'
pup_paths['P1T7'] = '../Pupillometry/Filtered/P1-task7.txt'
pup_paths['P1T8'] = '../Pupillometry/Filtered/P1-task8.txt'
pup_paths['P1T9'] = '../Pupillometry/Filtered/P1-task9.txt'
pup_paths['P1T10'] = '../Pupillometry/Filtered/P1-task10.txt'
pup_paths['P1T11'] = '../Pupillometry/Filtered/P1-task11.txt'
pup_paths['P1T12'] = '../Pupillometry/Filtered/P1-task12.txt'

pup_paths['P2T1'] = '../Pupillometry/Filtered/P2-task1.txt'
pup_paths['P2T2'] = '../Pupillometry/Filtered/P2-task2.txt'
pup_paths['P2T3'] = '../Pupillometry/Filtered/P2-task3.txt'
pup_paths['P2T4'] = '../Pupillometry/Filtered/P2-task4.txt'
pup_paths['P2T5'] = '../Pupillometry/Filtered/P2-task5.txt'
pup_paths['P2T6'] = '../Pupillometry/Filtered/P2-task6.txt'
pup_paths['P2T7'] = '../Pupillometry/Filtered/P2-task7.txt'
pup_paths['P2T8'] = '../Pupillometry/Filtered/P2-task8.txt'
pup_paths['P2T9'] = '../Pupillometry/Filtered/P2-task9.txt'
pup_paths['P2T10'] = '../Pupillometry/Filtered/P2-task10.txt'
pup_paths['P2T11'] = '../Pupillometry/Filtered/P2-task11.txt'
pup_paths['P2T12'] = '../Pupillometry/Filtered/P2-task12.txt'

pup_paths['P3T1'] = '../Pupillometry/Filtered/P3-task1.txt'
pup_paths['P3T2'] = '../Pupillometry/Filtered/P3-task2.txt'
pup_paths['P3T3'] = '../Pupillometry/Filtered/P3-task3.txt'
pup_paths['P3T4'] = '../Pupillometry/Filtered/P3-task4.txt'
pup_paths['P3T5'] = '../Pupillometry/Filtered/P3-task5.txt'
pup_paths['P3T6'] = '../Pupillometry/Filtered/P3-task6.txt'
pup_paths['P3T7'] = '../Pupillometry/Filtered/P3-task7.txt'
pup_paths['P3T8'] = '../Pupillometry/Filtered/P3-task8.txt'
pup_paths['P3T9'] = '../Pupillometry/Filtered/P3-task9.txt'
pup_paths['P3T10'] = '../Pupillometry/Filtered/P3-task10.txt'
pup_paths['P3T11'] = '../Pupillometry/Filtered/P3-task11.txt'
pup_paths['P3T12'] = '../Pupillometry/Filtered/P3-task12.txt'

pup_paths['P4T1'] = '../Pupillometry/Filtered/P4-task1.txt'
pup_paths['P4T2'] = '../Pupillometry/Filtered/P4-task2.txt'
pup_paths['P4T3'] = '../Pupillometry/Filtered/P4-task3.txt'
pup_paths['P4T4'] = '../Pupillometry/Filtered/P4-task4.txt'
pup_paths['P4T5'] = '../Pupillometry/Filtered/P4-task5.txt'
pup_paths['P4T6'] = '../Pupillometry/Filtered/P4-task6.txt'
pup_paths['P4T7'] = '../Pupillometry/Filtered/P4-task7.txt'
pup_paths['P4T8'] = '../Pupillometry/Filtered/P4-task8.txt'
pup_paths['P4T9'] = '../Pupillometry/Filtered/P4-task9.txt'
pup_paths['P4T10'] = '../Pupillometry/Filtered/P4-task10.txt'
pup_paths['P4T11'] = '../Pupillometry/Filtered/P4-task11.txt'
pup_paths['P4T12'] = '../Pupillometry/Filtered/P4-task12.txt'

# %% [markdown]
# ### DataFrames

# %%
P1T1 = pd.read_csv(pup_paths['P1T1'], sep=' ')
P1T2 = pd.read_csv(pup_paths['P1T2'], sep=' ')
P1T3 = pd.read_csv(pup_paths['P1T3'], sep=' ')
P1T4 = pd.read_csv(pup_paths['P1T4'], sep=' ')
P1T5 = pd.read_csv(pup_paths['P1T5'], sep=' ')
P1T6 = pd.read_csv(pup_paths['P1T6'], sep=' ')
P1T7 = pd.read_csv(pup_paths['P1T7'], sep=' ')
P1T8 = pd.read_csv(pup_paths['P1T8'], sep=' ')
P1T9 = pd.read_csv(pup_paths['P1T9'], sep=' ')
P1T10 = pd.read_csv(pup_paths['P1T10'], sep=' ')
P1T11 = pd.read_csv(pup_paths['P1T11'], sep=' ')
P1T12 = pd.read_csv(pup_paths['P1T12'], sep=' ')
P1 = [P1T1, P1T2, P1T3, P1T4, P1T5, P1T6, P1T7, P1T8, P1T9, P1T10, P1T11, P1T12]

P2T1 = pd.read_csv(pup_paths['P2T1'], sep=' ')
P2T2 = pd.read_csv(pup_paths['P2T2'], sep=' ')
P2T3 = pd.read_csv(pup_paths['P2T3'], sep=' ')
P2T4 = pd.read_csv(pup_paths['P2T4'], sep=' ')
P2T5 = pd.read_csv(pup_paths['P2T5'], sep=' ')
P2T6 = pd.read_csv(pup_paths['P2T6'], sep=' ')
P2T7 = pd.read_csv(pup_paths['P2T7'], sep=' ')
P2T8 = pd.read_csv(pup_paths['P2T8'], sep=' ')
P2T9 = pd.read_csv(pup_paths['P2T9'], sep=' ')
P2T10 = pd.read_csv(pup_paths['P2T10'], sep=' ')
P2T11 = pd.read_csv(pup_paths['P2T11'], sep=' ')
P2T12 = pd.read_csv(pup_paths['P2T12'], sep=' ')
P2 = [P2T1, P2T2, P2T3, P2T4, P2T5, P2T6, P2T7, P2T8, P2T9, P2T10, P2T11, P2T12]

P3T1 = pd.read_csv(pup_paths['P3T1'], sep=' ')
P3T2 = pd.read_csv(pup_paths['P3T2'], sep=' ')
P3T3 = pd.read_csv(pup_paths['P3T3'], sep=' ')
P3T4 = pd.read_csv(pup_paths['P3T4'], sep=' ')
P3T5 = pd.read_csv(pup_paths['P3T5'], sep=' ')
P3T6 = pd.read_csv(pup_paths['P3T6'], sep=' ')
P3T7 = pd.read_csv(pup_paths['P3T7'], sep=' ')
P3T8 = pd.read_csv(pup_paths['P3T8'], sep=' ')
P3T9 = pd.read_csv(pup_paths['P3T9'], sep=' ')
P3T10 = pd.read_csv(pup_paths['P3T10'], sep=' ')
P3T11 = pd.read_csv(pup_paths['P3T11'], sep=' ')
P3T12 = pd.read_csv(pup_paths['P3T12'], sep=' ')
P3 = [P3T1, P3T2, P3T3, P3T4, P3T5, P3T6, P3T7, P3T8, P3T9, P3T10, P3T11, P3T12]

P4T1 = pd.read_csv(pup_paths['P4T1'], sep=' ')
P4T2 = pd.read_csv(pup_paths['P4T2'], sep=' ')
P4T3 = pd.read_csv(pup_paths['P4T3'], sep=' ')
P4T4 = pd.read_csv(pup_paths['P4T4'], sep=' ')
P4T5 = pd.read_csv(pup_paths['P4T5'], sep=' ')
P4T6 = pd.read_csv(pup_paths['P4T6'], sep=' ')
P4T7 = pd.read_csv(pup_paths['P4T7'], sep=' ')
P4T8 = pd.read_csv(pup_paths['P4T8'], sep=' ')
P4T9 = pd.read_csv(pup_paths['P4T9'], sep=' ')
P4T10 = pd.read_csv(pup_paths['P4T10'], sep=' ')
P4T11 = pd.read_csv(pup_paths['P4T11'], sep=' ')
P4T12 = pd.read_csv(pup_paths['P4T12'], sep=' ')
P4 = [P4T1, P4T2, P4T3, P4T4, P4T5, P4T6, P4T7, P4T8, P4T9, P4T10, P4T11, P4T12]

# %% [markdown]
# ### Removing excess columns

# %%
def trim_df(participant):
    for df in participant:
        # Remove unwanted columns
        for i in df.columns:
            # Use only 'xmm_filled'
            if i != 'xmm_filled':
                df.drop(i, inplace=True, axis=1)

# %%
trim_df(P1)
trim_df(P2)
trim_df(P3)
trim_df(P4)

# %% [markdown]
# ### Making a dictionary of participants/tasks

# %%
dataframes = {}

for p in range(4):
    participant = 'P' + str(p + 1)
    dataframes[participant] = {}
    
for t in range(12):
    task = 'task' + str(t + 1)
    dataframes['P1'][task] = P1[t]
    dataframes['P2'][task] = P2[t]
    dataframes['P3'][task] = P3[t]
    dataframes['P4'][task] = P4[t]

# %%
dataframes['P1']['task5']
# Out:
#       xmm_filled
# 331     3.935429
# 332     3.921304
# 333     3.906121
# 334     3.897234
# 335     3.892549
# ...          ...
# 1989    3.728718
# 1990    3.728834
# 1991    3.728951
# 1992    3.729068
# 1993    3.729184
#
# [1663 rows x 1 columns]

# %% [markdown]
# ## Adding Z-Score

# %%
# Function for adding task Z-score to task by participants overall avg 
def p_mean_std(df):

    # Participant
    for prt in df:
        
        # container for participant mean/std
        part_tmp = []
        
        # Concatenating tasks
        for tsk in df[prt]:
            part_tmp.append(df[prt][tsk])            

        # Finding mean/std pr participant
        prt_mean = pd.concat(part_tmp).mean()[0]
        prt_std = pd.concat(part_tmp).std(ddof=0)[0]
        
        # Adding Z-score row pr task dataframe:
        for tsk in df[prt]:
            df[prt][tsk]['zscore'] = (df[prt][tsk] - prt_mean) / prt_std

# %%
# Applying the function
p_mean_std(dataframes)

# %%
dataframes['P1']['task5']
# Out:
#       xmm_filled    zscore
# 331     3.935429  0.396416
# 332     3.921304  0.370325
# 333     3.906121  0.342281
# 334     3.897234  0.325864
# 335     3.892549  0.317211
# ...          ...       ...
# 1989    3.728718  0.014593
# 1990    3.728834  0.014809
# 1991    3.728951  0.015024
# 1992    3.729068  0.015240
# 1993    3.729184  0.015455
#
# [1663 rows x 2 columns]

# %% [markdown]
# # Average Pupil Size

# %%
raw = 'xmm_filled'
zscore = 'zscore'

# %%
dataframes['P4']['task1'][raw].mean()
# Out:
# 2.325048767403417

# %%
dataframes['P4']['task1'][raw].std(ddof=0)
# Out:
# 0.07270565511525176

# %% [markdown]
# ### Finding the Mean and Std pr task

# %%
# Making a dictionary of Average Pupil Size for task of each participant:
avg_pup_dict = {}

#P
for prt in dataframes:
    # Participant
    avg_pup_dict[prt] = {}
    
    for tsk in dataframes[prt]:
        # Task mean/std
        avg_pup_dict[prt][tsk] = {}
        avg_pup_dict[prt][tsk][tsk+'_mean'] = dataframes[prt][tsk][raw].mean()
        avg_pup_dict[prt][tsk][tsk+'_std'] = dataframes[prt][tsk][raw].std(ddof=0)
        
        # Task Z-score
        avg_pup_dict[prt][tsk][tsk+'_zscore'] = dataframes[prt][tsk][zscore].mean()
        avg_pup_dict[prt][tsk][tsk+'_z_std'] = dataframes[prt][tsk][zscore].std(ddof=0)

# %%
avg_pup_dict['P4']['task1']
# Out:
# {'task1_mean': 2.325048767403417,
#  'task1_std': 0.07270565511525176,
#  'task1_zscore': -0.5054316379230088,
#  'task1_z_std': 0.09042358297051564}

# %%
# Printing the mean of the pupil size of each task pr participant
print('\nAverage Pupil Size (mm)')
for prt in avg_pup_dict:
    # Participant
    print(f'\n{prt}\t{"": <3}Mean{"": <5}\tStd{"": <5}\t Z-score\n')
    for tsk in avg_pup_dict[prt]:
        # The mean rounded to 5 decimals
        print(tsk, f'\t{"": <3}{avg_pup_dict[prt][tsk][tsk+"_mean"]:.5}{"": <3}\t{avg_pup_dict[prt][tsk][tsk+"_std"]:.5}{"": <3}\t{avg_pup_dict[prt][tsk][tsk+"_zscore"]: .5}')
    print('\n')
# Out:
# Average Pupil Size (mm)
#
# P1	   Mean     	Std     	 Z-score
#
# task1 	   3.0996   	0.21625   	-1.1475
# task2 	   3.0695   	0.23974   	-1.2031
# task3 	   3.7969   	0.305   	 0.14058
# task4 	   4.1511   	0.4146   	 0.79481
# task5 	   4.0317   	0.20785   	 0.5742
# task6 	   4.1084   	0.21938   	 0.71599
# task7 	   3.3303   	0.26134   	-0.7214
# task8 	   3.3538   	0.066495   	-0.6779
# task9 	   4.0672   	0.13952   	 0.63985
# task10 	   3.786   	0.24994   	 0.12041
# task11 	   3.4255   	0.23142   	-0.54558
# task12 	   3.6161   	0.19479   	-0.19344
#
#
#
# P2	   Mean     	Std     	 Z-score
#
# task1 	   6.687   	0.64486   	 0.5771
# task2 	   5.9804   	0.36804   	-0.68659
# task3 	   6.5126   	0.51148   	 0.26523
# task4 	   6.6728   	0.39542   	 0.5517
# task5 	   6.4158   	0.39956   	 0.092189
# task6 	   6.5162   	0.45252   	 0.27172
# task7 	   5.7713   	0.55681   	-1.0605
# task8 	   6.7924   	0.33162   	 0.76563
# task9 	   6.1246   	0.29527   	-0.42864
# ...

# %% [markdown]
# ## Plotting the Average Pupil Size of each task pr participant

# %%
# Making a list of labels
labels = []

# Task labels (similar for all participants)
for tsk in avg_pup_dict['P1']:
    labels.append(tsk)

# %% [markdown]
# ### Making lists for plotting bars and errorbars

# %%
# Making a list of Pupil Size means & std
avg_pup_plot = []
avg_pup_yerr = []

# Making a list of Z-score
avg_pup_plot_z = []


# Participant
for i, prt in enumerate(avg_pup_dict):
    avg_pup_plot.append([])
    avg_pup_yerr.append([])
    
    avg_pup_plot_z.append([])
    # Task
    for tsk in avg_pup_dict[prt]:
        avg_pup_plot[i].append(avg_pup_dict[prt][tsk][tsk+'_mean'])
        avg_pup_yerr[i].append(avg_pup_dict[prt][tsk][tsk+'_std'])
        
        avg_pup_plot_z[i].append(avg_pup_dict[prt][tsk][tsk+'_zscore'])

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('Average Pupil Size', fontsize=32)

rects1 = axs[0,0].bar(labels, avg_pup_plot[0], color='c')
rects2 = axs[0,1].bar(labels, avg_pup_plot[1], color='m')
rects3 = axs[1,0].bar(labels, avg_pup_plot[2], color='y')
rects4 = axs[1,1].bar(labels, avg_pup_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1)
axs[0,1].bar_label(rects2)
axs[1,0].bar_label(rects3)
axs[1,1].bar_label(rects4)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/pup_bar.pdf')
plt.show()

# %%
# Z-Score

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('Average Pupil Size (Z-Score Standardized)', fontsize=32)

rects1 = axs[0,0].bar(labels, avg_pup_plot_z[0], color='c')
rects2 = axs[0,1].bar(labels, avg_pup_plot_z[1], color='m')
rects3 = axs[1,0].bar(labels, avg_pup_plot_z[2], color='y')
rects4 = axs[1,1].bar(labels, avg_pup_plot_z[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].bar_label(rects1)
axs[0,1].bar_label(rects2)
axs[1,0].bar_label(rects3)
axs[1,1].bar_label(rects4)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/pup_plot_zscore.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('Average Pupil Size (w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, avg_pup_plot[0], yerr=avg_pup_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, avg_pup_plot[1], yerr=avg_pup_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, avg_pup_plot[2], yerr=avg_pup_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, avg_pup_plot[3], yerr=avg_pup_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/pup_errorbar.pdf')
plt.show()

# %% [markdown]
# ## Comparing Participants pr task for each case

# %%
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, axs = plt.subplots(figsize=(24,6))
rects1 = axs.bar(x - width/2, avg_pup_plot[0], width/2, label='P1')
rects2 = axs.bar(x, avg_pup_plot[1], width/2, label='P2')
rects3 = axs.bar(x + width/2, avg_pup_plot[2], width/2, label='P3')
rects4 = axs.bar(x + width, avg_pup_plot[3], width/2, label='P4')


# Add text for labels, title and custom x-axis tick labels, etc.
axs.set_ylabel('Pupil Size (mm) (Mean)', fontsize=16)
axs.set_title('Pupil Size by Participant Comparison', pad=16, fontsize=24)
axs.set_xticks(x+0.1, labels)
axs.legend()


# Adding bar labels (mean)
axs.bar_label(rects1, fmt='%.2f')
axs.bar_label(rects2, fmt='%.2f')
axs.bar_label(rects3, fmt='%.2f')
axs.bar_label(rects4, fmt='%.2f')

# Border between Impro and Scales
axs.axvline(x=3.6, ls=':', lw=2, c='r')


# Tightening, plotting and saving
fig.tight_layout()
plt.savefig('./plots/pup_participant_comparison_bar.pdf')  
plt.show()

# %%
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, axs = plt.subplots(figsize=(24,6))
rects1 = axs.bar(x - width/2, avg_pup_plot_z[0], width/2, label='P1')
rects2 = axs.bar(x, avg_pup_plot_z[1], width/2, label='P2')
rects3 = axs.bar(x + width/2, avg_pup_plot_z[2], width/2, label='P3')
rects4 = axs.bar(x + width, avg_pup_plot_z[3], width/2, label='P4')


# Add text for labels, title and custom x-axis tick labels, etc.
axs.set_ylabel('Pupil Size (mm) (Mean)', fontsize=16)
axs.set_title('Pupil Size by Participant Comparison (Z-score standardized)', pad=16, fontsize=24)
axs.set_xticks(x+0.1, labels)
axs.legend()


# Adding bar labels (mean)
axs.bar_label(rects1, fmt='%.2f', padding=2)
axs.bar_label(rects2, fmt='%.2f', padding=2)
axs.bar_label(rects3, fmt='%.2f', padding=2)
axs.bar_label(rects4, fmt='%.2f', padding=2)

# Border between Impro and Scales
axs.axvline(x=3.6, ls=':', lw=2, c='r')

# Tightening, plotting and saving
fig.tight_layout()
plt.savefig('./plots/pup_participant_comparison_plot_zscore.pdf')  
plt.show()

# %% [markdown]
# # Mean across participants (pr task)

# %%
# Making a new dataframe for Z-score means
task_avg = pd.DataFrame(index=np.arange(1,13))
task_avg.index.name = 'Task'

# Using the Z-score values
for prt in avg_pup_dict:
    prt_avg = []
    for tsk in avg_pup_dict[prt]:
        prt_avg.append(avg_pup_dict[prt][tsk][tsk+'_zscore'])
    task_avg[prt] = prt_avg
    
# Adding column with Means
task_avg['task_mean'] = task_avg.mean(axis=1)

# %%
task_avg
# Out:
#             P1        P2        P3        P4  task_mean
# Task
# 1    -1.147480  0.577101 -0.398526 -0.505432  -0.368584
# 2    -1.203067 -0.686593  0.176212 -0.782098  -0.623887
# 3     0.140581  0.265235 -1.360847 -0.072102  -0.256783
# 4     0.794809  0.551699 -0.306062 -0.687214   0.088308
# 5     0.574195  0.092189  1.656472  0.539362   0.715555
# 6     0.715993  0.271717  2.623251  1.973687   1.396162
# 7    -0.721403 -1.060513  1.202660  1.369743   0.197621
# 8    -0.677901  0.765627  1.770488  1.755955   0.903542
# 9     0.639849 -0.428641  1.201361  0.881845   0.573604
# 10    0.120408 -0.170596  1.106154  1.675307   0.682818
# 11   -0.545576 -0.291689  0.954701  1.113075   0.307628
# 12   -0.193437  0.206380  1.231270  1.729778   0.743498

# %%
fig, ax = plt.subplots(figsize=(16,6))

fig.suptitle('Average Pupil Size (Z-Score Standardized)', fontsize=26)

ax.bar(labels, task_avg['task_mean'], label='Pupil Size (Mean)')

ax.set_ylabel('Z-Score', fontsize=12)

# Border between Impro and Scales
ax.axvline(x=3.5, ls=':', lw=2, c='r', alpha=0.5)

ax.legend()

plt.tight_layout()
plt.savefig("./plots/pup_avg.pdf")
plt.plot()
# Out:
# []

# %% [markdown]
# ## Exporting Pupil plot data

# %%
import joblib

folder = './plot_data/'

# %%
joblib.dump(avg_pup_plot, folder+'avg_pup_plot')
joblib.dump(avg_pup_plot_z, folder+'avg_pup_plot_z')
# Out:
# ['./plot_data/avg_pup_plot_z']
