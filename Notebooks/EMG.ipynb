# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing EMG data

# %% [markdown]
# ### Paths

# %%
emg_paths = {}

emg_paths['P1T1'] = '../MoCap_output/EMG-P01-task1.txt'
emg_paths['P1T2'] = '../MoCap_output/EMG-P01-task2.txt'
emg_paths['P1T3'] = '../MoCap_output/EMG-P01-task3.txt'
emg_paths['P1T4'] = '../MoCap_output/EMG-P01-task4.txt'
emg_paths['P1T5'] = '../MoCap_output/EMG-P01-task5.txt'
emg_paths['P1T6'] = '../MoCap_output/EMG-P01-task6.txt'
emg_paths['P1T7'] = '../MoCap_output/EMG-P01-task7.txt'
emg_paths['P1T8'] = '../MoCap_output/EMG-P01-task8.txt'
emg_paths['P1T9'] = '../MoCap_output/EMG-P01-task9.txt'
emg_paths['P1T10'] = '../MoCap_output/EMG-P01-task10.txt'
emg_paths['P1T11'] = '../MoCap_output/EMG-P01-task11.txt'
emg_paths['P1T12'] = '../MoCap_output/EMG-P01-task12.txt'

emg_paths['P2T1'] = '../MoCap_output/EMG-P02-task1.txt'
emg_paths['P2T2'] = '../MoCap_output/EMG-P02-task2.txt'
emg_paths['P2T3'] = '../MoCap_output/EMG-P02-task3.txt'
emg_paths['P2T4'] = '../MoCap_output/EMG-P02-task4.txt'
emg_paths['P2T5'] = '../MoCap_output/EMG-P02-task5.txt'
emg_paths['P2T6'] = '../MoCap_output/EMG-P02-task6.txt'
emg_paths['P2T7'] = '../MoCap_output/EMG-P02-task7.txt'
emg_paths['P2T8'] = '../MoCap_output/EMG-P02-task8.txt'
emg_paths['P2T9'] = '../MoCap_output/EMG-P02-task9.txt'
emg_paths['P2T10'] = '../MoCap_output/EMG-P02-task10.txt'
emg_paths['P2T11'] = '../MoCap_output/EMG-P02-task11.txt'
emg_paths['P2T12'] = '../MoCap_output/EMG-P02-task12.txt'

emg_paths['P3T1'] = '../MoCap_output/EMG-P03-task1.txt'
emg_paths['P3T2'] = '../MoCap_output/EMG-P03-task2.txt'
emg_paths['P3T3'] = '../MoCap_output/EMG-P03-task3.txt'
emg_paths['P3T4'] = '../MoCap_output/EMG-P03-task4.txt'
emg_paths['P3T5'] = '../MoCap_output/EMG-P03-task5.txt'
emg_paths['P3T6'] = '../MoCap_output/EMG-P03-task6.txt'
emg_paths['P3T7'] = '../MoCap_output/EMG-P03-task7.txt'
emg_paths['P3T8'] = '../MoCap_output/EMG-P03-task8.txt'
emg_paths['P3T9'] = '../MoCap_output/EMG-P03-task9.txt'
emg_paths['P3T10'] = '../MoCap_output/EMG-P03-task10.txt'
emg_paths['P3T11'] = '../MoCap_output/EMG-P03-task11.txt'
emg_paths['P3T12'] = '../MoCap_output/EMG-P03-task12.txt'

emg_paths['P4T1'] = '../MoCap_output/EMG-P04-task1.txt'
emg_paths['P4T2'] = '../MoCap_output/EMG-P04-task2.txt'
emg_paths['P4T3'] = '../MoCap_output/EMG-P04-task3.txt'
emg_paths['P4T4'] = '../MoCap_output/EMG-P04-task4.txt'
emg_paths['P4T5'] = '../MoCap_output/EMG-P04-task5.txt'
emg_paths['P4T6'] = '../MoCap_output/EMG-P04-task6.txt'
emg_paths['P4T7'] = '../MoCap_output/EMG-P04-task7.txt'
emg_paths['P4T8'] = '../MoCap_output/EMG-P04-task8.txt'
emg_paths['P4T9'] = '../MoCap_output/EMG-P04-task9.txt'
emg_paths['P4T10'] = '../MoCap_output/EMG-P04-task10.txt'
emg_paths['P4T11'] = '../MoCap_output/EMG-P04-task11.txt'
emg_paths['P4T12'] = '../MoCap_output/EMG-P04-task12.txt'

# %% [markdown]
# ### DataFrames

# %%
P1T1 = pd.read_csv(emg_paths['P1T1'], sep=' ')
P1T2 = pd.read_csv(emg_paths['P1T2'], sep=' ')
P1T3 = pd.read_csv(emg_paths['P1T3'], sep=' ')
P1T4 = pd.read_csv(emg_paths['P1T4'], sep=' ')
P1T5 = pd.read_csv(emg_paths['P1T5'], sep=' ')
P1T6 = pd.read_csv(emg_paths['P1T6'], sep=' ')
P1T7 = pd.read_csv(emg_paths['P1T7'], sep=' ')
P1T8 = pd.read_csv(emg_paths['P1T8'], sep=' ')
P1T9 = pd.read_csv(emg_paths['P1T9'], sep=' ')
P1T10 = pd.read_csv(emg_paths['P1T10'], sep=' ')
P1T11 = pd.read_csv(emg_paths['P1T11'], sep=' ')
P1T12 = pd.read_csv(emg_paths['P1T12'], sep=' ')
P1 = [P1T1, P1T2, P1T3, P1T4, P1T5, P1T6, P1T7, P1T8, P1T9, P1T10, P1T11, P1T12]

P2T1 = pd.read_csv(emg_paths['P2T1'], sep=' ')
P2T2 = pd.read_csv(emg_paths['P2T2'], sep=' ')
P2T3 = pd.read_csv(emg_paths['P2T3'], sep=' ')
P2T4 = pd.read_csv(emg_paths['P2T4'], sep=' ')
P2T5 = pd.read_csv(emg_paths['P2T5'], sep=' ')
P2T6 = pd.read_csv(emg_paths['P2T6'], sep=' ')
P2T7 = pd.read_csv(emg_paths['P2T7'], sep=' ')
P2T8 = pd.read_csv(emg_paths['P2T8'], sep=' ')
P2T9 = pd.read_csv(emg_paths['P2T9'], sep=' ')
P2T10 = pd.read_csv(emg_paths['P2T10'], sep=' ')
P2T11 = pd.read_csv(emg_paths['P2T11'], sep=' ')
P2T12 = pd.read_csv(emg_paths['P2T12'], sep=' ')
P2 = [P2T1, P2T2, P2T3, P2T4, P2T5, P2T6, P2T7, P2T8, P2T9, P2T10, P2T11, P2T12]

P3T1 = pd.read_csv(emg_paths['P3T1'], sep=' ')
P3T2 = pd.read_csv(emg_paths['P3T2'], sep=' ')
P3T3 = pd.read_csv(emg_paths['P3T3'], sep=' ')
P3T4 = pd.read_csv(emg_paths['P3T4'], sep=' ')
P3T5 = pd.read_csv(emg_paths['P3T5'], sep=' ')
P3T6 = pd.read_csv(emg_paths['P3T6'], sep=' ')
P3T7 = pd.read_csv(emg_paths['P3T7'], sep=' ')
P3T8 = pd.read_csv(emg_paths['P3T8'], sep=' ')
P3T9 = pd.read_csv(emg_paths['P3T9'], sep=' ')
P3T10 = pd.read_csv(emg_paths['P3T10'], sep=' ')
P3T11 = pd.read_csv(emg_paths['P3T11'], sep=' ')
P3T12 = pd.read_csv(emg_paths['P3T12'], sep=' ')
P3 = [P3T1, P3T2, P3T3, P3T4, P3T5, P3T6, P3T7, P3T8, P3T9, P3T10, P3T11, P3T12]

P4T1 = pd.read_csv(emg_paths['P4T1'], sep=' ')
P4T2 = pd.read_csv(emg_paths['P4T2'], sep=' ')
P4T3 = pd.read_csv(emg_paths['P4T3'], sep=' ')
P4T4 = pd.read_csv(emg_paths['P4T4'], sep=' ')
P4T5 = pd.read_csv(emg_paths['P4T5'], sep=' ')
P4T6 = pd.read_csv(emg_paths['P4T6'], sep=' ')
P4T7 = pd.read_csv(emg_paths['P4T7'], sep=' ')
P4T8 = pd.read_csv(emg_paths['P4T8'], sep=' ')
P4T9 = pd.read_csv(emg_paths['P4T9'], sep=' ')
P4T10 = pd.read_csv(emg_paths['P4T10'], sep=' ')
P4T11 = pd.read_csv(emg_paths['P4T11'], sep=' ')
P4T12 = pd.read_csv(emg_paths['P4T12'], sep=' ')
P4 = [P4T1, P4T2, P4T3, P4T4, P4T5, P4T6, P4T7, P4T8, P4T9, P4T10, P4T11, P4T12]

# %% [markdown]
# ### Removing excess columns

# %%
def trim_df(participant):
    for df in participant:
        # Remove unwanted columns for EMG calculation
        for i in df.columns[:2]:
            df.drop(i, inplace=True, axis=1)
        for i in df.columns[-2:]:
            df.drop(i, inplace=True, axis=1)

# %%
trim_df(P1)
trim_df(P2)
trim_df(P3)
trim_df(P4)

# %% [markdown]
# ### Making a dictionary of participants/tasks

# %%
dataframes = {}

for p in range(4):
    participant = 'P' + str(p + 1)
    dataframes[participant] = {}
    
for t in range(12):
    task = 'task' + str(t + 1)
    dataframes['P1'][task] = P1[t]
    dataframes['P2'][task] = P2[t]
    dataframes['P3'][task] = P3[t]
    dataframes['P4'][task] = P4[t]

# %%
dataframes['P2']['task1']
# Out:
#        right_extensor  left_flexor  left_extensor  right_flexor
# 0          347.462846    10.773307    1890.715249      4.165362
# 1          345.493396    10.719164    1890.746884      4.121052
# 2          343.638036    10.655706    1890.575041      4.083679
# 3          341.901106    10.583931    1890.227631      4.053197
# 4          340.289042    10.504811    1889.746393      4.029558
# ...               ...          ...            ...           ...
# 89375      108.504236    36.085471     617.202939     18.931208
# 89376      109.791537    35.614560     638.010281     18.955718
# 89377      111.087617    35.115731     660.008037     18.970703
# 89378      112.389445    34.591753     683.232675     18.977654
# 89379      113.693445    34.045790     707.719344     18.978434
#
# [89380 rows x 4 columns]

# %% [markdown]
# # Average EMG

# %%
dataframes['P4']['task1'].mean()
# Out:
# left_flexor        10.799876
# right_extensor    201.727421
# left_extensor      73.054973
# right_flexor       44.965563
# dtype: float64

# %%
dataframes['P4']['task1'].std(ddof=0)
# Out:
# left_flexor       10.292817
# right_extensor    28.354108
# left_extensor     17.466298
# right_flexor      30.274101
# dtype: float64

# %%
# Making a dictionary of average EMG for each sensor of each task of each participant:
emg_dict = {}

for prt in dataframes:
    # Participant
    emg_dict[prt] = {}
    for tsk in dataframes[prt]:
        # Task
        emg_dict[prt][tsk] = {}
        for sns in dataframes[prt][tsk]:
            # Sensor
            emg_dict[prt][tsk][sns] = {}
            # Mean and Standard deviation
            emg_dict[prt][tsk][sns][sns+'_mean'] = dataframes[prt][tsk][sns].mean()
            emg_dict[prt][tsk][sns][sns+'_std'] = dataframes[prt][tsk][sns].std(ddof=0)

# %%
emg_dict['P4']['task1']
# Out:
# {'left_flexor': {'left_flexor_mean': 10.799876468534062,
#   'left_flexor_std': 10.292817421483011},
#  'right_extensor': {'right_extensor_mean': 201.72742118359193,
#   'right_extensor_std': 28.35410793481048},
#  'left_extensor': {'left_extensor_mean': 73.05497266428763,
#   'left_extensor_std': 17.466297598195354},
#  'right_flexor': {'right_flexor_mean': 44.965562771051665,
#   'right_flexor_std': 30.274100728005255}}

# %% [markdown]
# ## Defining cases
#
#
# **Case 1**: All sensors
#
#     Average of both flexor and extensor of each hand
#
# **Case 2**: Flexors (Both hands)
#
#     Average of flexors of both hands
#
# **Case 3**: Extensors (Both hands)
#
#     Average of extensors of both hands
#
# **Case 4**: Left hand extensor
#
#     Average of Left hand extensor
#
# **Case 5**: Right hand extensor
#
#     Average of Right hand extensor (EMG data of choice)

# %%
emg_cases = {}

# CASE 1
case = 'case1'
emg_cases[case] = {}

# Participant
for prt in dataframes:
    emg_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        emg_cases[case][prt][tsk] = {}
        emg_cases[case][prt][tsk][tsk+'_mean'] = []
        emg_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for sns in dataframes[prt][tsk]:            
            # Listing means
            emg_cases[case][prt][tsk][tsk+'_mean'].append(emg_dict[prt][tsk][sns][sns+'_mean'])         
        # Mean & std calculation
        emg_cases[case][prt][tsk][tsk+'_std'] = np.nanstd(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(emg_cases[case][prt][tsk][tsk+'_mean'])

# %%
# CASE 2
case = 'case2'
emg_cases[case] = {}

# Participant
for prt in dataframes:
    emg_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        emg_cases[case][prt][tsk] = {}
        emg_cases[case][prt][tsk][tsk+'_mean'] = []
        emg_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for sns in dataframes[prt][tsk]:
            if sns == 'left_flexor' or sns == 'right_flexor':
                # Listing means
                emg_cases[case][prt][tsk][tsk+'_mean'].append(emg_dict[prt][tsk][sns][sns+'_mean'])         
        # Mean & std calculation
        emg_cases[case][prt][tsk][tsk+'_std'] = np.nanstd(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(emg_cases[case][prt][tsk][tsk+'_mean'])

# %%
# CASE 3
case = 'case3'
emg_cases[case] = {}

# Participant
for prt in dataframes:
    emg_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        emg_cases[case][prt][tsk] = {}
        emg_cases[case][prt][tsk][tsk+'_mean'] = []
        emg_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for sns in dataframes[prt][tsk]:
            if sns == 'left_extensor' or sns == 'right_extensor':
                # Listing means
                emg_cases[case][prt][tsk][tsk+'_mean'].append(emg_dict[prt][tsk][sns][sns+'_mean'])         
        # Mean & std calculation
        emg_cases[case][prt][tsk][tsk+'_std'] = np.nanstd(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(emg_cases[case][prt][tsk][tsk+'_mean'])

# %%
# CASE 4
case = 'case4'
emg_cases[case] = {}

# Participant
for prt in dataframes:
    emg_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        emg_cases[case][prt][tsk] = {}
        emg_cases[case][prt][tsk][tsk+'_mean'] = []
        emg_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for sns in dataframes[prt][tsk]:
            if sns == 'left_extensor':
                # Listing means & std
                emg_cases[case][prt][tsk][tsk+'_mean'].append(emg_dict[prt][tsk][sns][sns+'_mean'])
                emg_cases[case][prt][tsk][tsk+'_std'].append(emg_dict[prt][tsk][sns][sns+'_std'])
                
        # Mean calculation
        emg_cases[case][prt][tsk][tsk+'_std'] = emg_cases[case][prt][tsk][tsk+'_std'][0] 
        emg_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(emg_cases[case][prt][tsk][tsk+'_mean'])

# %%
# CASE 5
case = 'case5'
emg_cases[case] = {}

# Participant
for prt in dataframes:
    emg_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        emg_cases[case][prt][tsk] = {}
        emg_cases[case][prt][tsk][tsk+'_mean'] = []
        emg_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for sns in dataframes[prt][tsk]:
            if sns == 'right_extensor':
                # Listing means & std
                emg_cases[case][prt][tsk][tsk+'_mean'].append(emg_dict[prt][tsk][sns][sns+'_mean'])
                emg_cases[case][prt][tsk][tsk+'_std'].append(emg_dict[prt][tsk][sns][sns+'_std'])
                
        # Mean calculation
        emg_cases[case][prt][tsk][tsk+'_std'] = emg_cases[case][prt][tsk][tsk+'_std'][0] 
        emg_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(emg_cases[case][prt][tsk][tsk+'_mean'])

# %%
# Printing the mean of each sensor of each task pr participant
print('\nCASE 1\t(Both hands – Both sensors)')
for prt in emg_cases['case1']:
    # Participant
    print(f'\n{prt}\t{"": <3}Mean{"": <5}\tStd\n')
    for tsk in emg_cases['case4'][prt]:
        # The mean rounded to 5 decimals
        print(tsk, f'\t{"": <3}{emg_cases["case1"][prt][tsk][tsk+"_mean"]:.5}{"": <3}\t{emg_cases["case1"][prt][tsk][tsk+"_std"]:.5}')
    print('\n')
# Out:
# CASE 1	(Both hands – Both sensors)
#
# P1	   Mean     	Std
#
# task1 	   22.469   	11.706
# task2 	   23.753   	10.233
# task3 	   24.569   	11.156
# task4 	   31.146   	8.2135
# task5 	   24.925   	10.052
# task6 	   34.128   	7.4605
# task7 	   31.76   	11.412
# task8 	   38.024   	9.6651
# task9 	   30.69   	9.2961
# task10 	   38.432   	8.5997
# task11 	   30.324   	15.192
# task12 	   37.948   	21.698
#
#
#
# P2	   Mean     	Std
#
# task1 	   468.86   	606.13
# task2 	   279.53   	408.33
# task3 	   245.3   	313.25
# task4 	   129.13   	156.16
# task5 	   424.59   	680.43
# task6 	   422.63   	638.26
# task7 	   464.29   	737.27
# task8 	   578.95   	938.22
# task9 	   467.85   	735.3
# task10 	   448.05   	706.86
# task11 	   606.12   	955.14
# task12 	   425.88   	656.65
#
#
#
# P3	   Mean     	Std
#
# task1 	   11.064   	5.1628
# task2 	   11.207   	3.5069
# task3 	   12.773   	5.1329
# task4 	   13.434   	4.6649
# task5 	   14.483   	5.5006
# task6 	   19.461   	7.4311
# task7 	   18.226   	7.1159
# task8 	   18.463   	6.3933
# task9 	   11.641   	6.5253
# task10 	   13.777   	7.3562
# task11 	   18.446   	6.0633
# task12 	   19.974   	7.3009
#
#
#
# P4	   Mean     	Std
#
# task1 	   82.637   	72.205
# task2 	   75.232   	65.208
# task3 	   96.33   	82.638
# task4 	   107.66   	80.497
# task5 	   98.867   	73.267
# task6 	   107.02   	74.547
# task7 	   102.23   	84.906
# task8 	   111.74   	81.192
# task9 	   109.63   	111.92
# task10 	   106.0   	115.7
# task11 	   125.09   	92.241
# task12 	   147.56   	98.657

# %% [markdown]
# ## Plotting the Average Pupil Size of each task pr participant

# %%
# Making a list of labels
labels = []

# Task labels (similar for all participants)
for tsk in emg_dict['P1']:
    labels.append(tsk)

# %% [markdown]
# ### Making lists for plotting bars and errorbars

# %%
# CASE 1

# Making a list of EMG means & std
emg_case1_plot = []
emg_case1_yerr = []
case = 'case1'

# Participant
for i, prt in enumerate(emg_cases[case]):
    emg_case1_plot.append([])
    emg_case1_yerr.append([])
    # Task
    for tsk in emg_cases[case][prt]:
        emg_case1_plot[i].append(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_case1_yerr[i].append(emg_cases[case][prt][tsk][tsk+'_std'])

        
# CASE 2

# Making a list of EMG means & std
emg_case2_plot = []
emg_case2_yerr = []
case = 'case2'

# Participant
for i, prt in enumerate(emg_cases[case]):
    emg_case2_plot.append([])
    emg_case2_yerr.append([])
    # Task
    for tsk in emg_cases[case][prt]:
        emg_case2_plot[i].append(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_case2_yerr[i].append(emg_cases[case][prt][tsk][tsk+'_std'])
        
        
# CASE 3

# Making a list of EMG means & std
emg_case3_plot = []
emg_case3_yerr = []
case = 'case3'

# Participant
for i, prt in enumerate(emg_cases[case]):
    emg_case3_plot.append([])
    emg_case3_yerr.append([])
    # Task
    for tsk in emg_cases[case][prt]:
        emg_case3_plot[i].append(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_case3_yerr[i].append(emg_cases[case][prt][tsk][tsk+'_std'])
        
        
# CASE 4

# Making a list of EMG means & std
emg_case4_plot = []
emg_case4_yerr = []
case = 'case4'

# Participant
for i, prt in enumerate(emg_cases[case]):
    emg_case4_plot.append([])
    emg_case4_yerr.append([])
    # Task
    for tsk in emg_cases[case][prt]:
        emg_case4_plot[i].append(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_case4_yerr[i].append(emg_cases[case][prt][tsk][tsk+'_std'])
        
        
# CASE 5

# Making a list of EMG means & std
emg_case5_plot = []
emg_case5_yerr = []
case = 'case5'

# Participant
for i, prt in enumerate(emg_cases[case]):
    emg_case5_plot.append([])
    emg_case5_yerr.append([])
    # Task
    for tsk in emg_cases[case][prt]:
        emg_case5_plot[i].append(emg_cases[case][prt][tsk][tsk+'_mean'])
        emg_case5_yerr[i].append(emg_cases[case][prt][tsk][tsk+'_std'])

# %% [markdown]
# ## Case 1
#
# #### Both hands – Both sensors

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 1 – All sensors (normalized)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case1_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case1_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case1_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case1_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case1_bar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 1 – All sensors (normalized w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case1_plot[0], yerr=emg_case1_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, emg_case1_plot[1], yerr=emg_case1_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, emg_case1_plot[2], yerr=emg_case1_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, emg_case1_plot[3], yerr=emg_case1_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case1_errorbar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 1 – All sensors', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case1_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case1_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case1_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case1_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case1_bar.pdf')
plt.show()

# %% [markdown]
# ## Case 2
# #### Both hands – Flexors

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 2 – Flexors (both hands – normalized)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case2_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case2_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case2_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case2_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case2_bar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 2 – Flexors (both hands – normalized w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case2_plot[0], yerr=emg_case2_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, emg_case2_plot[1], yerr=emg_case2_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, emg_case2_plot[2], yerr=emg_case2_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, emg_case2_plot[3], yerr=emg_case2_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case2_errorbar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 2 – Flexors (both hands)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case2_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case2_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case2_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case2_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case2_bar.pdf')
plt.show()

# %% [markdown]
# ## Case 3
# #### Both hands – Extensors

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 3 – Extensors (both hands – normalized)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case3_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case3_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case3_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case3_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case3_bar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 3 – Extensors (both hands – normalized w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case3_plot[0], yerr=emg_case3_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, emg_case3_plot[1], yerr=emg_case3_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, emg_case3_plot[2], yerr=emg_case3_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, emg_case3_plot[3], yerr=emg_case3_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case3_errorbar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 3 – Extensors (both hands)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case3_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case3_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case3_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case3_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case3_bar.pdf')
plt.show()

# %% [markdown]
# ## Case 4
# #### Left hand – Extensors

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 4 – Left hand (extensor – normalized)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case4_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case4_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case4_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case4_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case4_bar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 4 – Left hand (extensor – normalized w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case4_plot[0], yerr=emg_case4_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, emg_case4_plot[1], yerr=emg_case4_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, emg_case4_plot[2], yerr=emg_case4_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, emg_case4_plot[3], yerr=emg_case4_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case4_errorbar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 4 – Left hand (extensor)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case4_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case4_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case4_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case4_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case4_bar.pdf')
plt.show()

# %% [markdown]
# ## Case 5
# #### Right hand – Extensor

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 5 – Right hand (extensor – normalized)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case5_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case5_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case5_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case5_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case5_bar_norm.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('CASE 5 – Right hand (extensor – normalized w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case5_plot[0], yerr=emg_case5_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, emg_case5_plot[1], yerr=emg_case5_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, emg_case5_plot[2], yerr=emg_case5_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, emg_case5_plot[3], yerr=emg_case5_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

fig.tight_layout()
plt.savefig('./plots/emg_case5_errorbar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 5 – Right hand (extensor)', fontsize=32)

rects1 = axs[0,0].bar(labels, emg_case5_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case5_plot[1], color='m')
rects3 = axs[1,0].bar(labels, emg_case5_plot[2], color='y')
rects4 = axs[1,1].bar(labels, emg_case5_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].bar_label(rects1, label_type='center')
axs[0,1].bar_label(rects2, label_type='center')
axs[1,0].bar_label(rects3, label_type='center')
axs[1,1].bar_label(rects4, label_type='center')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case5_bar.pdf')
plt.show()

# %% [markdown]
# # Comparing Cases
#
# **Cases:**
# 1. Both hands – Both sensors
# 2. Both hands – Flexor
# 3. Both hands – Extensor
# 4. Left hand – Extensor
# 5. Right hand – Extensor
#
# **Comparisons**
# - Case 2 vs. Case 3
# - Case Comparison (1,2,3)
#
#
# - Case 4 vs. Case 5
# - Case Comparison (1,4,5)
#
#
# - "Participant by Case" Comparison
#
#
# - Comparison matrix

# %% [markdown]
# ### Case 2 vs. Case 3

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('EMG Case 2 vs 3 Comparison (per Participant – normalized)', fontsize=32)

rects1_1 = axs[0,0].bar(x - width/2, emg_case2_plot[0], width, label='Case 2 (Flexors)')
rects1_2 = axs[0,0].bar(x + width/2, emg_case3_plot[0], width, label='Case 3 (Extensors)')

rects2_1 = axs[0,1].bar(x - width/2, emg_case2_plot[1], width, label='Case 2 (Flexors)')
rects2_2 = axs[0,1].bar(x + width/2, emg_case3_plot[1], width, label='Case 3 (Extensors)')

rects3_1 = axs[1,0].bar(x - width/2, emg_case2_plot[2], width, label='Case 2 (Flexors)')
rects3_2 = axs[1,0].bar(x + width/2, emg_case3_plot[2], width, label='Case 3 (Extensors)')

rects4_1 = axs[1,1].bar(x - width/2, emg_case2_plot[3], width, label='Case 2 (Flexors)')
rects4_2 = axs[1,1].bar(x + width/2, emg_case3_plot[3], width, label='Case 3 (Extensors)')

axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[1,0].set_title('P3', fontsize=24)
axs[1,1].set_title('P4', fontsize=24)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].legend(loc=2, fontsize=14)
axs[0,1].legend(loc=2, fontsize=14)
axs[1,0].legend(loc=2, fontsize=14)
axs[1,1].legend(loc=2, fontsize=14)

axs[0,0].bar_label(rects1_1, label_type='center')
axs[0,0].bar_label(rects1_2, label_type='edge', padding=3)

axs[0,1].bar_label(rects2_1, label_type='center')
axs[0,1].bar_label(rects2_2, label_type='edge', padding=3)

axs[1,0].bar_label(rects3_1, label_type='center')
axs[1,0].bar_label(rects3_2, label_type='edge', padding=3)

axs[1,1].bar_label(rects4_1, label_type='center')
axs[1,1].bar_label(rects4_2, label_type='edge', padding=3)

axs[0,0].set_xticks(x, labels)
axs[0,1].set_xticks(x, labels)
axs[1,0].set_xticks(x, labels)
axs[1,1].set_xticks(x, labels)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case_2vs3_bar_norm.pdf')
plt.show()

# %% [markdown]
# ### Case 1-2-3 comparison

# %%
x = np.arange(len(labels))  # the label locations
width = 0.75  # the width of the bars

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('EMG Case 1-2-3 Comparison (per Participant - normalized)', fontsize=32)

rects1_1 = axs[0,0].bar(x - width/3, emg_case1_plot[0], width/3, label='Case 1 (All)')
rects1_2 = axs[0,0].bar(x, emg_case2_plot[0], width/3, label='Case 2 (Flexors)')
rects1_3 = axs[0,0].bar(x + width/3, emg_case3_plot[0], width/3, label='Case 3 (Extensors)')

rects2_1 = axs[0,1].bar(x - width/3, emg_case1_plot[1], width/3, label='Case 1 (All)')
rects2_2 = axs[0,1].bar(x, emg_case2_plot[1], width/3, label='Case 2 (Flexors)')
rects2_3 = axs[0,1].bar(x + width/3, emg_case3_plot[1], width/3, label='Case 3 (Extensors)')

rects3_1 = axs[1,0].bar(x - width/3, emg_case1_plot[2], width/3, label='Case 1 (All)')
rects3_2 = axs[1,0].bar(x, emg_case2_plot[2], width/3, label='Case 2 (Flexors)')
rects3_3 = axs[1,0].bar(x + width/3, emg_case3_plot[2], width/3, label='Case 3 (Extensors)')

rects4_1 = axs[1,1].bar(x - width/3, emg_case1_plot[3], width/3, label='Case 1 (All)')
rects4_2 = axs[1,1].bar(x, emg_case2_plot[3], width/3, label='Case 2 (Flexors)')
rects4_3 = axs[1,1].bar(x + width/3, emg_case3_plot[3], width/3, label='Case 3 (Extensors)')

axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[1,0].set_title('P3', fontsize=24)
axs[1,1].set_title('P4', fontsize=24)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].legend(loc=2, fontsize=14)
axs[0,1].legend(loc=2, fontsize=14)
axs[1,0].legend(loc=2, fontsize=14)
axs[1,1].legend(loc=2, fontsize=14)

axs[0,0].set_xticks(x, labels)
axs[0,1].set_xticks(x, labels)
axs[1,0].set_xticks(x, labels)
axs[1,1].set_xticks(x, labels)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case123_comparison_bar_norm.pdf')
plt.show()

# %% [markdown]
# ### Case 4 vs. Case 5

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('EMG Case 4 vs 5 Comparison (per Participant – normalized)', fontsize=32)

rects1_1 = axs[0,0].bar(x - width/2, emg_case4_plot[0], width, label='Case 4 (Left Extensor)')
rects1_2 = axs[0,0].bar(x + width/2, emg_case5_plot[0], width, label='Case 5 (Right Extensor)')

rects2_1 = axs[0,1].bar(x - width/2, emg_case4_plot[1], width, label='Case 4 (Left Extensor)')
rects2_2 = axs[0,1].bar(x + width/2, emg_case5_plot[1], width, label='Case 5 (Right Extensor)')

rects3_1 = axs[1,0].bar(x - width/2, emg_case4_plot[2], width, label='Case 4 (Left Extensor)')
rects3_2 = axs[1,0].bar(x + width/2, emg_case5_plot[2], width, label='Case 5 (Right Extensor)')

rects4_1 = axs[1,1].bar(x - width/2, emg_case4_plot[3], width, label='Case 4 (Left Extensor)')
rects4_2 = axs[1,1].bar(x + width/2, emg_case5_plot[3], width, label='Case 5 (Right Extensor)')

axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[1,0].set_title('P3', fontsize=24)
axs[1,1].set_title('P4', fontsize=24)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].legend(loc=2, fontsize=14)
axs[0,1].legend(loc=2, fontsize=14)
axs[1,0].legend(loc=2, fontsize=14)
axs[1,1].legend(loc=2, fontsize=14)

axs[0,0].bar_label(rects1_1, label_type='center')
axs[0,0].bar_label(rects1_2, label_type='edge', padding=3)

axs[0,1].bar_label(rects2_1, label_type='center')
axs[0,1].bar_label(rects2_2, label_type='edge', padding=3)

axs[1,0].bar_label(rects3_1, label_type='center')
axs[1,0].bar_label(rects3_2, label_type='edge', padding=3)

axs[1,1].bar_label(rects4_1, label_type='center')
axs[1,1].bar_label(rects4_2, label_type='edge', padding=3)

axs[0,0].set_xticks(x, labels)
axs[0,1].set_xticks(x, labels)
axs[1,0].set_xticks(x, labels)
axs[1,1].set_xticks(x, labels)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case_4vs5_bar_norm.pdf')
plt.show()

# %% [markdown]
# ### Case 1-4-5 comparison

# %%
x = np.arange(len(labels))  # the label locations
width = 0.75  # the width of the bars

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=False)

fig.suptitle('EMG Case 1-4-5 Comparison (per Participant - normalized)', fontsize=32)

rects1_1 = axs[0,0].bar(x - width/3, emg_case1_plot[0], width/3, label='Case 1 (All)')
rects1_2 = axs[0,0].bar(x, emg_case4_plot[0], width/3, label='Case 4 (Left Extensor)')
rects1_3 = axs[0,0].bar(x + width/3, emg_case5_plot[0], width/3, label='Case 5 (Right Extensor)')

rects2_1 = axs[0,1].bar(x - width/3, emg_case1_plot[1], width/3, label='Case 1 (All)')
rects2_2 = axs[0,1].bar(x, emg_case4_plot[1], width/3, label='Case 4 (Left Extensor)')
rects2_3 = axs[0,1].bar(x + width/3, emg_case5_plot[1], width/3, label='Case 5 (Right Extensor)')

rects3_1 = axs[1,0].bar(x - width/3, emg_case1_plot[2], width/3, label='Case 1 (All)')
rects3_2 = axs[1,0].bar(x, emg_case4_plot[2], width/3, label='Case 4 (Left Extensor)')
rects3_3 = axs[1,0].bar(x + width/3, emg_case5_plot[2], width/3, label='Case 5 (Right Extensor)')

rects4_1 = axs[1,1].bar(x - width/3, emg_case1_plot[3], width/3, label='Case 1 (All)')
rects4_2 = axs[1,1].bar(x, emg_case4_plot[3], width/3, label='Case 4 (Left Extensor)')
rects4_3 = axs[1,1].bar(x + width/3, emg_case5_plot[3], width/3, label='Case 5 (Right Extensor)')

axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[1,0].set_title('P3', fontsize=24)
axs[1,1].set_title('P4', fontsize=24)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].legend(loc=2, fontsize=14)
axs[0,1].legend(loc=2, fontsize=14)
axs[1,0].legend(loc=2, fontsize=14)
axs[1,1].legend(loc=2, fontsize=14)

axs[0,0].set_xticks(x, labels)
axs[0,1].set_xticks(x, labels)
axs[1,0].set_xticks(x, labels)
axs[1,1].set_xticks(x, labels)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/emg_case145_comparison_bar_norm.pdf')
plt.show()

# %% [markdown]
# ## Comparing Participants pr task for each case

# %%
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, axs = plt.subplots(5,1,figsize=(24,30), sharey=False)
rects1 = axs[0].bar(x - width/2, emg_case1_plot[0], width/2, label='P1')
rects2 = axs[0].bar(x, emg_case1_plot[1], width/2, label='P2')
rects3 = axs[0].bar(x + width/2, emg_case1_plot[2], width/2, label='P3')
rects4 = axs[0].bar(x + width, emg_case1_plot[3], width/2, label='P4')

rects5 = axs[1].bar(x - width/2, emg_case2_plot[0], width/2, label='P1')
rects6 = axs[1].bar(x, emg_case2_plot[1], width/2, label='P2')
rects7 = axs[1].bar(x + width/2, emg_case2_plot[2], width/2, label='P3')
rects8 = axs[1].bar(x + width, emg_case2_plot[3], width/2, label='P4')

rects9 = axs[2].bar(x - width/2, emg_case3_plot[0], width/2, label='P1')
rects10 = axs[2].bar(x, emg_case3_plot[1], width/2, label='P2')
rects11 = axs[2].bar(x + width/2, emg_case3_plot[2], width/2, label='P3')
rects12 = axs[2].bar(x + width, emg_case3_plot[3], width/2, label='P4')

rects13 = axs[3].bar(x - width/2, emg_case4_plot[0], width/2, label='P1')
rects14 = axs[3].bar(x, emg_case4_plot[1], width/2, label='P2')
rects15 = axs[3].bar(x + width/2, emg_case4_plot[2], width/2, label='P3')
rects16 = axs[3].bar(x + width, emg_case4_plot[3], width/2, label='P4')

rects17 = axs[4].bar(x - width/2, emg_case5_plot[0], width/2, label='P1')
rects18 = axs[4].bar(x, emg_case5_plot[1], width/2, label='P2')
rects19 = axs[4].bar(x + width/2, emg_case5_plot[2], width/2, label='P3')
rects20 = axs[4].bar(x + width, emg_case5_plot[3], width/2, label='P4')

# Add text for labels, title and custom x-axis tick labels, etc.
fig.suptitle('EMG by Participant Comparison (normalized)', y=0.994, fontsize=32)

axs[0].set_ylabel('EMG (Mean)', fontsize=16)
axs[0].set_title('CASE 1 (All sensors)', pad=16, fontsize=24)
axs[0].set_xticks(x+0.1, labels)
axs[0].legend(fontsize=14)

axs[1].set_ylabel('EMG (Mean)', fontsize=16)
axs[1].set_title('CASE 2 (Both hands – Flexors))', pad=16, fontsize=24)
axs[1].set_xticks(x+0.1, labels)
axs[1].legend(fontsize=14)

axs[2].set_ylabel('EMG (Mean)', fontsize=16)
axs[2].set_title('CASE 3 (Both hands – Extensors)', pad=16, fontsize=24)
axs[2].set_xticks(x+0.1, labels)
axs[2].legend(fontsize=14)

axs[3].set_ylabel('EMG (Mean)', fontsize=16)
axs[3].set_title('CASE 4 (Left hand – Extensors)', pad=16, fontsize=24)
axs[3].set_xticks(x+0.1, labels)
axs[3].legend(fontsize=14)

axs[4].set_ylabel('EMG (Mean)', fontsize=16)
axs[4].set_title('CASE 4 (Right Hand – Extensor)', pad=16, fontsize=24)
axs[4].set_xticks(x+0.1, labels)
axs[4].legend(fontsize=14)

# Adding bar labels (mean)
axs[0].bar_label(rects1, padding=3)
axs[0].bar_label(rects2, padding=3)
axs[0].bar_label(rects3, padding=3)
axs[0].bar_label(rects4, padding=3)

axs[1].bar_label(rects5, padding=3)
axs[1].bar_label(rects6, padding=3)
axs[1].bar_label(rects7, padding=3)
axs[1].bar_label(rects8, padding=3)

axs[2].bar_label(rects9, padding=3)
axs[2].bar_label(rects10, padding=3)
axs[2].bar_label(rects11, padding=3)
axs[2].bar_label(rects12, padding=3)

axs[3].bar_label(rects13, padding=3)
axs[3].bar_label(rects14, padding=3)
axs[3].bar_label(rects15, padding=3)
axs[3].bar_label(rects16, padding=3)

axs[4].bar_label(rects17, padding=3)
axs[4].bar_label(rects18, padding=3)
axs[4].bar_label(rects19, padding=3)
axs[4].bar_label(rects20, padding=3)

# Border between Impro and Scales
axs[0].axvline(x=3.6, ls=':', lw=2, c='r')
axs[1].axvline(x=3.6, ls=':', lw=2, c='r')
axs[2].axvline(x=3.6, ls=':', lw=2, c='r')
axs[3].axvline(x=3.6, ls=':', lw=2, c='r')
axs[4].axvline(x=3.6, ls=':', lw=2, c='r')

# Tightening, plotting and saving
fig.tight_layout()
plt.savefig('./plots/emg_participant_comparison_bar_norm.pdf')  
plt.show()

# %%
fig, axs = plt.subplots(5, 4, figsize=(36, 20), sharey=False)
fig.suptitle('Comparison Matrix (normalized)', fontsize=36)

# Case 1
rects1 = axs[0,0].bar(labels, emg_case1_plot[0], color='c')
rects2 = axs[0,1].bar(labels, emg_case1_plot[1], color='m')
rects3 = axs[0,2].bar(labels, emg_case1_plot[2], color='y')
rects4 = axs[0,3].bar(labels, emg_case1_plot[3], color='g')

# Case 3
rects5 = axs[1,0].bar(labels, emg_case2_plot[0], color='c')
rects6 = axs[1,1].bar(labels, emg_case2_plot[1], color='m')
rects7 = axs[1,2].bar(labels, emg_case2_plot[2], color='y')
rects8 = axs[1,3].bar(labels, emg_case2_plot[3], color='g')

# Case 3
rects9 = axs[2,0].bar(labels, emg_case3_plot[0], color='c')
rects10 = axs[2,1].bar(labels, emg_case3_plot[1], color='m')
rects11 = axs[2,2].bar(labels, emg_case3_plot[2], color='y')
rects12 = axs[2,3].bar(labels, emg_case3_plot[3], color='g')

# Case 4
rects13 = axs[3,0].bar(labels, emg_case4_plot[0], color='c')
rects14 = axs[3,1].bar(labels, emg_case4_plot[1], color='m')
rects15 = axs[3,2].bar(labels, emg_case4_plot[2], color='y')
rects16 = axs[3,3].bar(labels, emg_case4_plot[3], color='g')

# Case 5
rects17 = axs[4,0].bar(labels, emg_case5_plot[0], color='c')
rects18 = axs[4,1].bar(labels, emg_case5_plot[1], color='m')
rects19 = axs[4,2].bar(labels, emg_case5_plot[2], color='y')
rects20 = axs[4,3].bar(labels, emg_case5_plot[3], color='g')

# Column Titles (Participants)
axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[0,2].set_title('P3', fontsize=24)
axs[0,3].set_title('P4', fontsize=24)

# Row Titles (Cases)
axs[0,0].set_ylabel('Case 1', fontsize=24)
axs[1,0].set_ylabel('Case 2', fontsize=24)
axs[2,0].set_ylabel('Case 3', fontsize=24)
axs[3,0].set_ylabel('Case 4', fontsize=24)
axs[4,0].set_ylabel('Case 5', fontsize=24)

# Bar labels (EMG mean value)
axs[0,0].bar_label(rects1)
axs[0,1].bar_label(rects2)
axs[0,2].bar_label(rects3)
axs[0,3].bar_label(rects4)

axs[1,0].bar_label(rects5)
axs[1,1].bar_label(rects6)
axs[1,2].bar_label(rects7)
axs[1,3].bar_label(rects8)

axs[2,0].bar_label(rects9)
axs[2,1].bar_label(rects10)
axs[2,2].bar_label(rects11)
axs[2,3].bar_label(rects12)

axs[3,0].bar_label(rects13)
axs[3,1].bar_label(rects14)
axs[3,2].bar_label(rects15)
axs[3,3].bar_label(rects16)

axs[4,0].bar_label(rects17)
axs[4,1].bar_label(rects18)
axs[4,2].bar_label(rects19)
axs[4,3].bar_label(rects20)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,2].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,3].axvline(x=3.5, ls=':', lw=2, c='r')

axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,2].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,3].axvline(x=3.5, ls=':', lw=2, c='r')

axs[2,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[2,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[2,2].axvline(x=3.5, ls=':', lw=2, c='r')
axs[2,3].axvline(x=3.5, ls=':', lw=2, c='r')

axs[3,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[3,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[3,2].axvline(x=3.5, ls=':', lw=2, c='r')
axs[3,3].axvline(x=3.5, ls=':', lw=2, c='r')

axs[4,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[4,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[4,2].axvline(x=3.5, ls=':', lw=2, c='r')
axs[4,3].axvline(x=3.5, ls=':', lw=2, c='r')

# Exporting & Plotting
fig.tight_layout()
plt.savefig('./plots/emg_comparison_matrix_norm.pdf')
plt.show()

# %% [markdown]
# ## Exporting EMG plot data

# %%
import joblib

folder = './plot_data/'

# %%
joblib.dump(emg_case1_plot, folder+'emg_case1_plot')
joblib.dump(emg_case2_plot, folder+'emg_case2_plot')
joblib.dump(emg_case3_plot, folder+'emg_case3_plot')
joblib.dump(emg_case4_plot, folder+'emg_case4_plot')
joblib.dump(emg_case5_plot, folder+'emg_case5_plot')
# Out:
# ['./plot_data/emg_case5_plot']
