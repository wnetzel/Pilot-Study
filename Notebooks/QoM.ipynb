# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing MoCap data

# %% [markdown]
# ### Paths

# %%
vel_paths = {}

vel_paths['P1T1'] = '../MoCap_output/Velocity-P01-task1.txt'
vel_paths['P1T2'] = '../MoCap_output/Velocity-P01-task2.txt'
vel_paths['P1T3'] = '../MoCap_output/Velocity-P01-task3.txt'
vel_paths['P1T4'] = '../MoCap_output/Velocity-P01-task4.txt'
vel_paths['P1T5'] = '../MoCap_output/Velocity-P01-task5.txt'
vel_paths['P1T6'] = '../MoCap_output/Velocity-P01-task6.txt'
vel_paths['P1T7'] = '../MoCap_output/Velocity-P01-task7.txt'
vel_paths['P1T8'] = '../MoCap_output/Velocity-P01-task8.txt'
vel_paths['P1T9'] = '../MoCap_output/Velocity-P01-task9.txt'
vel_paths['P1T10'] = '../MoCap_output/Velocity-P01-task10.txt'
vel_paths['P1T11'] = '../MoCap_output/Velocity-P01-task11.txt'
vel_paths['P1T12'] = '../MoCap_output/Velocity-P01-task12.txt'

vel_paths['P2T1'] = '../MoCap_output/Velocity-P02-task1.txt'
vel_paths['P2T2'] = '../MoCap_output/Velocity-P02-task2.txt'
vel_paths['P2T3'] = '../MoCap_output/Velocity-P02-task3.txt'
vel_paths['P2T4'] = '../MoCap_output/Velocity-P02-task4.txt'
vel_paths['P2T5'] = '../MoCap_output/Velocity-P02-task5.txt'
vel_paths['P2T6'] = '../MoCap_output/Velocity-P02-task6.txt'
vel_paths['P2T7'] = '../MoCap_output/Velocity-P02-task7.txt'
vel_paths['P2T8'] = '../MoCap_output/Velocity-P02-task8.txt'
vel_paths['P2T9'] = '../MoCap_output/Velocity-P02-task9.txt'
vel_paths['P2T10'] = '../MoCap_output/Velocity-P02-task10.txt'
vel_paths['P2T11'] = '../MoCap_output/Velocity-P02-task11.txt'
vel_paths['P2T12'] = '../MoCap_output/Velocity-P02-task12.txt'

vel_paths['P3T1'] = '../MoCap_output/Velocity-P03-task1.txt'
vel_paths['P3T2'] = '../MoCap_output/Velocity-P03-task2.txt'
vel_paths['P3T3'] = '../MoCap_output/Velocity-P03-task3.txt'
vel_paths['P3T4'] = '../MoCap_output/Velocity-P03-task4.txt'
vel_paths['P3T5'] = '../MoCap_output/Velocity-P03-task5.txt'
vel_paths['P3T6'] = '../MoCap_output/Velocity-P03-task6.txt'
vel_paths['P3T7'] = '../MoCap_output/Velocity-P03-task7.txt'
vel_paths['P3T8'] = '../MoCap_output/Velocity-P03-task8.txt'
vel_paths['P3T9'] = '../MoCap_output/Velocity-P03-task9.txt'
vel_paths['P3T10'] = '../MoCap_output/Velocity-P03-task10.txt'
vel_paths['P3T11'] = '../MoCap_output/Velocity-P03-task11.txt'
vel_paths['P3T12'] = '../MoCap_output/Velocity-P03-task12.txt'

vel_paths['P4T1'] = '../MoCap_output/Velocity-P04-task1.txt'
vel_paths['P4T2'] = '../MoCap_output/Velocity-P04-task2.txt'
vel_paths['P4T3'] = '../MoCap_output/Velocity-P04-task3.txt'
vel_paths['P4T4'] = '../MoCap_output/Velocity-P04-task4.txt'
vel_paths['P4T5'] = '../MoCap_output/Velocity-P04-task5.txt'
vel_paths['P4T6'] = '../MoCap_output/Velocity-P04-task6.txt'
vel_paths['P4T7'] = '../MoCap_output/Velocity-P04-task7.txt'
vel_paths['P4T8'] = '../MoCap_output/Velocity-P04-task8.txt'
vel_paths['P4T9'] = '../MoCap_output/Velocity-P04-task9.txt'
vel_paths['P4T10'] = '../MoCap_output/Velocity-P04-task10.txt'
vel_paths['P4T11'] = '../MoCap_output/Velocity-P04-task11.txt'
vel_paths['P4T12'] = '../MoCap_output/Velocity-P04-task12.txt'

# %% [markdown]
# ### DataFrames

# %%
P1T1 = pd.read_csv(vel_paths['P1T1'], sep=' ')
P1T2 = pd.read_csv(vel_paths['P1T2'], sep=' ')
P1T3 = pd.read_csv(vel_paths['P1T3'], sep=' ')
P1T4 = pd.read_csv(vel_paths['P1T4'], sep=' ')
P1T5 = pd.read_csv(vel_paths['P1T5'], sep=' ')
P1T6 = pd.read_csv(vel_paths['P1T6'], sep=' ')
P1T7 = pd.read_csv(vel_paths['P1T7'], sep=' ')
P1T8 = pd.read_csv(vel_paths['P1T8'], sep=' ')
P1T9 = pd.read_csv(vel_paths['P1T9'], sep=' ')
P1T10 = pd.read_csv(vel_paths['P1T10'], sep=' ')
P1T11 = pd.read_csv(vel_paths['P1T11'], sep=' ')
P1T12 = pd.read_csv(vel_paths['P1T12'], sep=' ')
P1 = [P1T1, P1T2, P1T3, P1T4, P1T5, P1T6, P1T7, P1T8, P1T9, P1T10, P1T11, P1T12]

P2T1 = pd.read_csv(vel_paths['P2T1'], sep=' ')
P2T2 = pd.read_csv(vel_paths['P2T2'], sep=' ')
P2T3 = pd.read_csv(vel_paths['P2T3'], sep=' ')
P2T4 = pd.read_csv(vel_paths['P2T4'], sep=' ')
P2T5 = pd.read_csv(vel_paths['P2T5'], sep=' ')
P2T6 = pd.read_csv(vel_paths['P2T6'], sep=' ')
P2T7 = pd.read_csv(vel_paths['P2T7'], sep=' ')
P2T8 = pd.read_csv(vel_paths['P2T8'], sep=' ')
P2T9 = pd.read_csv(vel_paths['P2T9'], sep=' ')
P2T10 = pd.read_csv(vel_paths['P2T10'], sep=' ')
P2T11 = pd.read_csv(vel_paths['P2T11'], sep=' ')
P2T12 = pd.read_csv(vel_paths['P2T12'], sep=' ')
P2 = [P2T1, P2T2, P2T3, P2T4, P2T5, P2T6, P2T7, P2T8, P2T9, P2T10, P2T11, P2T12]

P3T1 = pd.read_csv(vel_paths['P3T1'], sep=' ')
P3T2 = pd.read_csv(vel_paths['P3T2'], sep=' ')
P3T3 = pd.read_csv(vel_paths['P3T3'], sep=' ')
P3T4 = pd.read_csv(vel_paths['P3T4'], sep=' ')
P3T5 = pd.read_csv(vel_paths['P3T5'], sep=' ')
P3T6 = pd.read_csv(vel_paths['P3T6'], sep=' ')
P3T7 = pd.read_csv(vel_paths['P3T7'], sep=' ')
P3T8 = pd.read_csv(vel_paths['P3T8'], sep=' ')
P3T9 = pd.read_csv(vel_paths['P3T9'], sep=' ')
P3T10 = pd.read_csv(vel_paths['P3T10'], sep=' ')
P3T11 = pd.read_csv(vel_paths['P3T11'], sep=' ')
P3T12 = pd.read_csv(vel_paths['P3T12'], sep=' ')
P3 = [P3T1, P3T2, P3T3, P3T4, P3T5, P3T6, P3T7, P3T8, P3T9, P3T10, P3T11, P3T12]

P4T1 = pd.read_csv(vel_paths['P4T1'], sep=' ')
P4T2 = pd.read_csv(vel_paths['P4T2'], sep=' ')
P4T3 = pd.read_csv(vel_paths['P4T3'], sep=' ')
P4T4 = pd.read_csv(vel_paths['P4T4'], sep=' ')
P4T5 = pd.read_csv(vel_paths['P4T5'], sep=' ')
P4T6 = pd.read_csv(vel_paths['P4T6'], sep=' ')
P4T7 = pd.read_csv(vel_paths['P4T7'], sep=' ')
P4T8 = pd.read_csv(vel_paths['P4T8'], sep=' ')
P4T9 = pd.read_csv(vel_paths['P4T9'], sep=' ')
P4T10 = pd.read_csv(vel_paths['P4T10'], sep=' ')
P4T11 = pd.read_csv(vel_paths['P4T11'], sep=' ')
P4T12 = pd.read_csv(vel_paths['P4T12'], sep=' ')
P4 = [P4T1, P4T2, P4T3, P4T4, P4T5, P4T6, P4T7, P4T8, P4T9, P4T10, P4T11, P4T12]

# %% [markdown]
# ### Removing excess columns

# %%
def trim_df(participant):
    for df in participant:
        # Remove unwanted markers for QoM calculation
        for i in df.columns:
            # Remove static piano and clap marker
            if i == 'Piano_LF' or i == 'Piano_LB' or i == 'Piano_RF' or i == 'Piano_RB' or i == 'Hollywood':
                df.drop(i, inplace=True, axis=1)
            # Remove wrist markers
            elif i == 'L_Wrist_L' or i == 'L_Wrist_R' or i == 'R_Wrist_L' or i == 'R_Wrist_R':
                df.drop(i, inplace=True, axis=1)
        # Remove non-marker columns (index, timestamp, newtime, task)
        for i in df.columns[-4:]:
            df.drop(i, inplace=True, axis=1)

# %%
trim_df(P1)
trim_df(P2)
trim_df(P3)
trim_df(P4)

# %% [markdown]
# ### Making a dictionary of participants/tasks

# %%
dataframes = {}

for p in range(4):
    participant = 'P' + str(p + 1)
    dataframes[participant] = {}
    
for t in range(12):
    task = 'task' + str(t + 1)
    dataframes['P1'][task] = P1[t]
    dataframes['P2'][task] = P2[t]
    dataframes['P3'][task] = P3[t]
    dataframes['P4'][task] = P4[t]

# %%
dataframes['P4']['task10']
# Out:
#           Head  L_Shoulder  R_Shoulder      Back  L_Elbow   R_Elbow    L_Hand  \
# 0     0.333152    0.085100    0.163065  0.096699        0  0.286634  0.015365
# 1     0.351267    0.090772    0.143303  0.091088        0  0.354669  0.011951
# 2     0.366491    0.095204    0.128084  0.084198        0  0.439106  0.010814
# 3     0.386304    0.100986    0.115544  0.078833        0  0.518108  0.014590
# 4     0.405794    0.103144    0.104207  0.074085        0  0.562111  0.014209
# ...        ...         ...         ...       ...      ...       ...       ...
# 2172  0.086030    0.023500    0.104939  0.036289        0  0.543800  0.005505
# 2173  0.086552    0.020492    0.108210  0.035227        0  0.547870  0.005164
# 2174  0.085631    0.016319    0.109981  0.035975        0  0.544310  0.008650
# 2175  0.087056    0.012519    0.113363  0.039869        0  0.552304  0.009154
# 2176  0.088115    0.012181    0.120748  0.045899        0  0.565657  0.010246
#
#         R_Hand  Sustain_Foot
# ...

# %% [markdown]
# ### Replace zeroes with NaN

# %%
for prt in dataframes:
    for tsk in dataframes[prt]:
        for sns in dataframes[prt][tsk]:
            try:
                print(f"{prt} {tsk} {sns}: {dataframes[prt][tsk][sns].value_counts()[0]} zeroes replaced with 'NaN'")
                dataframes[prt][tsk][sns].replace(0, np.nan, inplace=True)
            except:
                continue
# Out:
# P4 task8 L_Elbow: 832 zeroes replaced with 'NaN'
# P4 task9 L_Elbow: 6411 zeroes replaced with 'NaN'
# P4 task10 L_Elbow: 2177 zeroes replaced with 'NaN'

# %%
dataframes['P4']['task8']
# Out:
#           Head  L_Shoulder  R_Shoulder      Back   L_Elbow   R_Elbow  \
# 0     0.293953    0.070624    0.097902  0.060661       NaN  0.345941
# 1     0.313198    0.071333    0.101694  0.061935       NaN  0.319697
# 2     0.327351    0.069999    0.104602  0.063121       NaN  0.299834
# 3     0.343548    0.074063    0.105277  0.062163       NaN  0.285918
# 4     0.355753    0.072870    0.107537  0.061321       NaN  0.278592
# ...        ...         ...         ...       ...       ...       ...
# 5952  0.092483    0.061763    0.113271  0.095356  0.922340  1.307284
# 5953  0.093738    0.058776    0.107141  0.095862  0.949497  1.286768
# 5954  0.094484    0.056618    0.099404  0.093100  0.970990  1.296857
# 5955  0.097193    0.056305    0.087878  0.087920  0.982000  1.331023
# 5956  0.097268    0.061978    0.076878  0.082748  0.995800  1.357976
#
#         L_Hand    R_Hand  Sustain_Foot
# 0     0.349845  0.718856      0.002156
# 1     0.334961  0.654596      0.004356
# ...

# %% [markdown]
# # QoM

# %%
dataframes['P4']['task12']['Head'].mean()
# Out:
# 0.15487479655796027

# %%
dataframes['P4']['task12']['Head'].std(ddof=0)
# Out:
# 0.10587424587710602

# %%
# Making a dictionary of QoM for each marker of each task of each participant:
qom_dict = {}

for prt in dataframes:
    # Participant
    qom_dict[prt] = {}
    for tsk in dataframes[prt]:
        # Task
        qom_dict[prt][tsk] = {}
        for mrk in dataframes[prt][tsk]:
            # Marker
            qom_dict[prt][tsk][mrk] = {}
            # Mean and Standard deviation
            qom_dict[prt][tsk][mrk][mrk+'_mean'] = dataframes[prt][tsk][mrk].mean()
            qom_dict[prt][tsk][mrk][mrk+'_std'] = dataframes[prt][tsk][mrk].std(ddof=0)

# %%
qom_dict['P4']['task12']['Head']
# Out:
# {'Head_mean': 0.15487479655796027, 'Head_std': 0.10587424587710602}

# %% [markdown]
# ## Defining cases
#
#
# **Case 1**: All markers (except wrist markers)
#
#     Too much motion centered around hands with both hand and double wrist markers (3 markers pr hand)
#
# **Case 2**: Except head marker
#
#     To plot the combined markers of the body vs only head marker
#
# **Case 3**: Only head marker

# %%
qom_cases = {}

# CASE 1
case = 'case1'
qom_cases[case] = {}

# Participant
for prt in dataframes:
    qom_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        qom_cases[case][prt][tsk] = {}
        qom_cases[case][prt][tsk][tsk+'_mean'] = []
        qom_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for mrk in dataframes[prt][tsk]:            
            # Listing means
            qom_cases[case][prt][tsk][tsk+'_mean'].append(qom_dict[prt][tsk][mrk][mrk+'_mean'])         
        # Mean & std calculation
        qom_cases[case][prt][tsk][tsk+'_std'] = np.nanstd(qom_cases[case][prt][tsk][tsk+'_mean'])
        qom_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(qom_cases[case][prt][tsk][tsk+'_mean'])

# %%
# CASE 2
case = 'case2'
qom_cases[case] = {}

# Participant
for prt in dataframes:
    qom_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        qom_cases[case][prt][tsk] = {}
        qom_cases[case][prt][tsk][tsk+'_mean'] = []
        qom_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for mrk in dataframes[prt][tsk]:
            if mrk != 'Head':
                # Listing means
                qom_cases[case][prt][tsk][tsk+'_mean'].append(qom_dict[prt][tsk][mrk][mrk+'_mean'])         
        # Mean & std calculation
        qom_cases[case][prt][tsk][tsk+'_std'] = np.nanstd(qom_cases[case][prt][tsk][tsk+'_mean'])
        qom_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(qom_cases[case][prt][tsk][tsk+'_mean'])

# %%
# CASE 3
case = 'case3'
qom_cases[case] = {}

# Participant
for prt in dataframes:
    qom_cases[case][prt] = {}
    # Task
    for tsk in dataframes[prt]:
        qom_cases[case][prt][tsk] = {}
        qom_cases[case][prt][tsk][tsk+'_mean'] = []
        qom_cases[case][prt][tsk][tsk+'_std'] = []
        
        # Marker
        for mrk in dataframes[prt][tsk]:
            if mrk == 'Head':
                # Listing means & stds
                qom_cases[case][prt][tsk][tsk+'_mean'].append(qom_dict[prt][tsk][mrk][mrk+'_mean'])
                qom_cases[case][prt][tsk][tsk+'_std'].append(qom_dict[prt][tsk][mrk][mrk+'_std'])                
        # Mean & std calculation
        qom_cases[case][prt][tsk][tsk+'_mean'] = np.nanmean(qom_cases[case][prt][tsk][tsk+'_mean'])
        qom_cases[case][prt][tsk][tsk+'_std'] = qom_cases[case][prt][tsk][tsk+'_std'][0]

# %%
print(qom_cases['case1']['P1']['task1'])
print(qom_cases['case2']['P1']['task1'])
print(qom_cases['case3']['P1']['task1'])
# Out:
# {'task1_mean': 0.22885808908842428, 'task1_std': 0.10936592831157001}
# {'task1_mean': 0.20115108798807518, 'task1_std': 0.08091302966834318}
# {'task1_mean': 0.45051409789121716, 'task1_std': 0.45974123413983986}

# %%
# Printing the mean of each marker of each task pr participant
print('\nCASE 1')
for prt in qom_cases['case1']:
    # Participant
    print(f'\n{prt}\t{"": <3}Mean{"": <5}\tStd\n')
    for tsk in qom_cases['case1'][prt]:
        # The mean rounded to 5 decimals
        print(tsk, f'\t{"": <3}{qom_cases["case1"][prt][tsk][tsk+"_mean"]:.5}{"": <3}\t{qom_cases["case1"][prt][tsk][tsk+"_std"]:.5}')
    print('\n')
# Out:
# CASE 1
#
# P1	   Mean     	Std
#
# task1 	   0.22886   	0.10937
# task2 	   0.24458   	0.13382
# task3 	   0.21961   	0.13584
# task4 	   0.40359   	0.25168
# task5 	   0.13292   	0.087987
# task6 	   0.4268   	0.26853
# task7 	   0.21989   	0.1292
# task8 	   0.45595   	0.16427
# task9 	   0.29032   	0.18451
# task10 	   0.43336   	0.26257
# task11 	   0.16211   	0.16428
# task12 	   0.3947   	0.30398
#
#
#
# P2	   Mean     	Std
#
# task1 	   0.15168   	0.066219
# task2 	   0.17744   	0.078015
# task3 	   0.18676   	0.10705
# task4 	   0.29061   	0.18888
# task5 	   0.28792   	0.098968
# task6 	   0.30873   	0.058437
# task7 	   0.21752   	0.093696
# task8 	   0.17694   	0.069749
# task9 	   0.14157   	0.086446
# task10 	   0.187   	0.131
# task11 	   0.2782   	0.068674
# task12 	   0.16757   	0.066637
#
#
#
# P3	   Mean     	Std
#
# task1 	   0.15886   	0.093549
# task2 	   0.21739   	0.13384
# task3 	   0.25774   	0.10745
# task4 	   0.26829   	0.15633
# ...

# %% [markdown]
# ## Plotting the QoM of each task pr participant

# %%
# Making a list of labels
labels = []

# Task labels (similar for all participants)
for tsk in qom_dict['P1']:
    labels.append(tsk)

# %% [markdown]
# ### Making lists for plotting bars and errorbars

# %%
# CASE 1

# Making a list of QoM means & std
qom_case1_plot = []
qom_case1_yerr = []
case = 'case1'

# Participant
for i, prt in enumerate(qom_cases[case]):
    qom_case1_plot.append([])
    qom_case1_yerr.append([])
    # Task
    for tsk in qom_cases[case][prt]:
        qom_case1_plot[i].append(qom_cases[case][prt][tsk][tsk+'_mean'])
        qom_case1_yerr[i].append(qom_cases[case][prt][tsk][tsk+'_std'])

        
# CASE 2

# Making a list of QoM means & std
qom_case2_plot = []
qom_case2_yerr = []
case = 'case2'

# Participant
for i, prt in enumerate(qom_cases[case]):
    qom_case2_plot.append([])
    qom_case2_yerr.append([])
    # Task
    for tsk in qom_cases[case][prt]:
        qom_case2_plot[i].append(qom_cases[case][prt][tsk][tsk+'_mean'])
        qom_case2_yerr[i].append(qom_cases[case][prt][tsk][tsk+'_std'])
        
        
# CASE 3

# Making a list of QoM means & std
qom_case3_plot = []
qom_case3_yerr = []
case = 'case3'

# Participant
for i, prt in enumerate(qom_cases[case]):
    qom_case3_plot.append([])
    qom_case3_yerr.append([])
    # Task
    for tsk in qom_cases[case][prt]:
        qom_case3_plot[i].append(qom_cases[case][prt][tsk][tsk+'_mean'])
        qom_case3_yerr[i].append(qom_cases[case][prt][tsk][tsk+'_std'])

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 1 – all markers', fontsize=32)

rects1 = axs[0,0].bar(labels, qom_case1_plot[0], color='c')
rects2 = axs[0,1].bar(labels, qom_case1_plot[1], color='m')
rects3 = axs[1,0].bar(labels, qom_case1_plot[2], color='y')
rects4 = axs[1,1].bar(labels, qom_case1_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].bar_label(rects1, fmt='%.5f')
axs[0,1].bar_label(rects2, fmt='%.5f')
axs[1,0].bar_label(rects3, fmt='%.5f')
axs[1,1].bar_label(rects4, fmt='%.5f')

fig.tight_layout()
plt.savefig('./plots/qom_case1_bar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 1 – all markers (w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, qom_case1_plot[0], yerr=qom_case1_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, qom_case1_plot[1], yerr=qom_case1_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, qom_case1_plot[2], yerr=qom_case1_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, qom_case1_plot[3], yerr=qom_case1_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].bar_label(rects1, label_type='center', fmt='%.5f')
axs[0,1].bar_label(rects2, label_type='center', fmt='%.5f')
axs[1,0].bar_label(rects3, label_type='center', fmt='%.5f')
axs[1,1].bar_label(rects4, label_type='center', fmt='%.5f')

fig.tight_layout()
plt.savefig('./plots/qom_case1_errorbar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 2 – except head marker', fontsize=32)

rects1 = axs[0,0].bar(labels, qom_case2_plot[0], color='c')
rects2 = axs[0,1].bar(labels, qom_case2_plot[1], color='m')
rects3 = axs[1,0].bar(labels, qom_case2_plot[2], color='y')
rects4 = axs[1,1].bar(labels, qom_case2_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].bar_label(rects1, fmt='%.5f')
axs[0,1].bar_label(rects2, fmt='%.5f')
axs[1,0].bar_label(rects3, fmt='%.5f')
axs[1,1].bar_label(rects4, fmt='%.5f')

fig.tight_layout()
plt.savefig('./plots/qom_case2_bar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 2 – except head marker (w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, qom_case2_plot[0], yerr=qom_case2_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, qom_case2_plot[1], yerr=qom_case2_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, qom_case2_plot[2], yerr=qom_case2_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, qom_case2_plot[3], yerr=qom_case2_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].bar_label(rects1, label_type='center', fmt='%.5f')
axs[0,1].bar_label(rects2, label_type='center', fmt='%.5f')
axs[1,0].bar_label(rects3, label_type='center', fmt='%.5f')
axs[1,1].bar_label(rects4, label_type='center', fmt='%.5f')

fig.tight_layout()
plt.savefig('./plots/qom_case2_errorbar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 3 – only head marker', fontsize=32)

rects1 = axs[0,0].bar(labels, qom_case3_plot[0], color='c')
rects2 = axs[0,1].bar(labels, qom_case3_plot[1], color='m')
rects3 = axs[1,0].bar(labels, qom_case3_plot[2], color='y')
rects4 = axs[1,1].bar(labels, qom_case3_plot[3], color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].bar_label(rects1, fmt='%.5f')
axs[0,1].bar_label(rects2, fmt='%.5f')
axs[1,0].bar_label(rects3, fmt='%.5f')
axs[1,1].bar_label(rects4, fmt='%.5f')

fig.tight_layout()
plt.savefig('./plots/qom_case3_bar.pdf')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('CASE 3 – only head marker (w/errorbars)', fontsize=32)

rects1 = axs[0,0].bar(labels, qom_case3_plot[0], yerr=qom_case3_yerr[0], capsize=6, color='c')
rects2 = axs[0,1].bar(labels, qom_case3_plot[1], yerr=qom_case3_yerr[1], capsize=6, color='m')
rects3 = axs[1,0].bar(labels, qom_case3_plot[2], yerr=qom_case3_yerr[2], capsize=6, color='y')
rects4 = axs[1,1].bar(labels, qom_case3_plot[3], yerr=qom_case3_yerr[3], capsize=6, color='g')

axs[0,0].set_title('P1', fontsize=16)
axs[0,1].set_title('P2', fontsize=16)
axs[1,0].set_title('P3', fontsize=16)
axs[1,1].set_title('P4', fontsize=16)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].bar_label(rects1, label_type='center', fmt='%.5f')
axs[0,1].bar_label(rects2, label_type='center', fmt='%.5f')
axs[1,0].bar_label(rects3, label_type='center', fmt='%.5f')
axs[1,1].bar_label(rects4, label_type='center', fmt='%.5f')

fig.tight_layout()
plt.savefig('./plots/qom_case3_errorbar.pdf')
plt.show()

# %% [markdown]
# ## Comparing Cases
#
# - Case 2 vs Case 3
# - All cases

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('QoM Case 2 vs 3 Comparison (per Participant)', fontsize=32)

rects1_1 = axs[0,0].bar(x - width/2, qom_case2_plot[0], width, label='Case 2 (w/o head)')
rects1_2 = axs[0,0].bar(x + width/2, qom_case3_plot[0], width, label='Case 3 (only head)')

rects2_1 = axs[0,1].bar(x - width/2, qom_case2_plot[1], width, label='Case 2 (w/o head)')
rects2_2 = axs[0,1].bar(x + width/2, qom_case3_plot[1], width, label='Case 3 (only head)')

rects3_1 = axs[1,0].bar(x - width/2, qom_case2_plot[2], width, label='Case 2 (w/o head)')
rects3_2 = axs[1,0].bar(x + width/2, qom_case3_plot[2], width, label='Case 3 (only head)')

rects4_1 = axs[1,1].bar(x - width/2, qom_case2_plot[3], width, label='Case 2 (w/o head)')
rects4_2 = axs[1,1].bar(x + width/2, qom_case3_plot[3], width, label='Case 3 (only head)')

axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[1,0].set_title('P3', fontsize=24)
axs[1,1].set_title('P4', fontsize=24)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].legend(loc=2, fontsize=14)
axs[0,1].legend(loc=2, fontsize=14)
axs[1,0].legend(loc=2, fontsize=14)
axs[1,1].legend(loc=2, fontsize=14)

axs[0,0].bar_label(rects1_1, fmt='%.2f')
axs[0,0].bar_label(rects1_2, fmt='%.2f')

axs[0,1].bar_label(rects2_1, fmt='%.2f')
axs[0,1].bar_label(rects2_2, fmt='%.2f')

axs[1,0].bar_label(rects3_1, fmt='%.2f')
axs[1,0].bar_label(rects3_2, fmt='%.2f')

axs[1,1].bar_label(rects4_1, fmt='%.2f')
axs[1,1].bar_label(rects4_2, fmt='%.2f')

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

axs[0,0].set_xticks(x, labels)
axs[0,1].set_xticks(x, labels)
axs[1,0].set_xticks(x, labels)
axs[1,1].set_xticks(x, labels)

fig.tight_layout()
plt.savefig('./plots/qom_case_2vs3_bar.pdf')
plt.show()

# %%
x = np.arange(len(labels))  # the label locations
width = 0.75  # the width of the bars

fig, axs = plt.subplots(2, 2, figsize=(24, 12), sharey=True)

fig.suptitle('QoM Case Comparison (per Participant)', fontsize=32)

rects1_1 = axs[0,0].bar(x - width/3, qom_case1_plot[0], width/3, label='Case 1 (all)')
rects1_2 = axs[0,0].bar(x, qom_case2_plot[0], width/3, label='Case 2 (body)')
rects1_3 = axs[0,0].bar(x + width/3, qom_case3_plot[0], width/3, label='Case 3 (head)')

rects2_1 = axs[0,1].bar(x - width/3, qom_case1_plot[1], width/3, label='Case 1 (all)')
rects2_2 = axs[0,1].bar(x, qom_case2_plot[1], width/3, label='Case 2 (body)')
rects2_3 = axs[0,1].bar(x + width/3, qom_case3_plot[1], width/3, label='Case 3 (head)')

rects3_1 = axs[1,0].bar(x - width/3, qom_case1_plot[2], width/3, label='Case 1 (all)')
rects3_2 = axs[1,0].bar(x, qom_case2_plot[2], width/3, label='Case 2 (body)')
rects3_3 = axs[1,0].bar(x + width/3, qom_case3_plot[2], width/3, label='Case 3 (head)')

rects4_1 = axs[1,1].bar(x - width/3, qom_case1_plot[3], width/3, label='Case 1 (all)')
rects4_2 = axs[1,1].bar(x, qom_case2_plot[3], width/3, label='Case 2 (body)')
rects4_3 = axs[1,1].bar(x + width/3, qom_case3_plot[3], width/3, label='Case 3 (head)')

axs[0,0].set_title('P1', fontsize=24)
axs[0,1].set_title('P2', fontsize=24)
axs[1,0].set_title('P3', fontsize=24)
axs[1,1].set_title('P4', fontsize=24)

axs[0,0].set_ylim(0)
axs[0,1].set_ylim(0)
axs[1,0].set_ylim(0)
axs[1,1].set_ylim(0)

axs[0,0].legend(loc=2, fontsize=14)
axs[0,1].legend(loc=2, fontsize=14)
axs[1,0].legend(loc=2, fontsize=14)
axs[1,1].legend(loc=2, fontsize=14)

axs[0,0].set_xticks(x, labels)
axs[0,1].set_xticks(x, labels)
axs[1,0].set_xticks(x, labels)
axs[1,1].set_xticks(x, labels)

# Border between Impro and Scales
axs[0,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[0,1].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,0].axvline(x=3.5, ls=':', lw=2, c='r')
axs[1,1].axvline(x=3.5, ls=':', lw=2, c='r')

fig.tight_layout()
plt.savefig('./plots/qom_case_comparison_bar.pdf')
plt.show()

# %% [markdown]
# ## Comparing Participants pr task for each case

# %%
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, axs = plt.subplots(3,1,figsize=(24,18), sharey=True)
rects1 = axs[0].bar(x - width/2, qom_case1_plot[0], width/2, label='P1')
rects2 = axs[0].bar(x, qom_case1_plot[1], width/2, label='P2')
rects3 = axs[0].bar(x + width/2, qom_case1_plot[2], width/2, label='P3')
rects4 = axs[0].bar(x + width, qom_case1_plot[3], width/2, label='P4')

rects5 = axs[1].bar(x - width/2, qom_case2_plot[0], width/2, label='P1')
rects6 = axs[1].bar(x, qom_case2_plot[1], width/2, label='P2')
rects7 = axs[1].bar(x + width/2, qom_case2_plot[2], width/2, label='P3')
rects8 = axs[1].bar(x + width, qom_case2_plot[3], width/2, label='P4')

rects9 = axs[2].bar(x - width/2, qom_case3_plot[0], width/2, label='P1')
rects10 = axs[2].bar(x, qom_case3_plot[1], width/2, label='P2')
rects11 = axs[2].bar(x + width/2, qom_case3_plot[2], width/2, label='P3')
rects12 = axs[2].bar(x + width, qom_case3_plot[3], width/2, label='P4')

# Add text for labels, title and custom x-axis tick labels, etc.
fig.suptitle('QoM by Participant Comparison', y=0.994, fontsize=32)

axs[0].set_ylabel('QoM (Mean)', fontsize=16)
axs[0].set_title('CASE 1 (all markers)', pad=16, fontsize=24)
axs[0].set_xticks(x+0.1, labels)
axs[0].legend(fontsize=14)

axs[1].set_ylabel('QoM (Mean)', fontsize=16)
axs[1].set_title('CASE 2 (body)', pad=16, fontsize=24)
axs[1].set_xticks(x+0.1, labels)
axs[1].legend(fontsize=14)

axs[2].set_ylabel('QoM (Mean)', fontsize=16)
axs[2].set_title('CASE 3 (head)', pad=16, fontsize=24)
axs[2].set_xticks(x+0.1, labels)
axs[2].legend(fontsize=14)

# Adding bar labels (mean)
axs[0].bar_label(rects1, fmt='%.2f')
axs[0].bar_label(rects2, fmt='%.2f')
axs[0].bar_label(rects3, fmt='%.2f')
axs[0].bar_label(rects4, fmt='%.2f')

axs[1].bar_label(rects5, fmt='%.2f')
axs[1].bar_label(rects6, fmt='%.2f')
axs[1].bar_label(rects7, fmt='%.2f')
axs[1].bar_label(rects8, fmt='%.2f')

axs[2].bar_label(rects9, fmt='%.2f')
axs[2].bar_label(rects10, fmt='%.2f')
axs[2].bar_label(rects11, fmt='%.2f')
axs[2].bar_label(rects12, fmt='%.2f')

# Border between Impro and Scales
axs[0].axvline(x=3.6, ls=':', lw=2, c='r')
axs[1].axvline(x=3.6, ls=':', lw=2, c='r')
axs[2].axvline(x=3.6, ls=':', lw=2, c='r')

# Tightening, plotting and saving
fig.tight_layout()
plt.savefig('./plots/qom_participant_comparison_bar.pdf')  
plt.show()

# %%
# Printing the mean of each task pr participant
for prt in qom_dict:
    # Participant
    print('\n'+prt+'\n')
    for tsk in qom_dict[prt]:
        print('\n'+tsk+'\t\tMean\t\tStd\n')
        for mrk in qom_dict[prt][tsk]:
            # The mean rounded to 5 decimals
            try:
                print(f'{mrk: <10} \t{qom_dict[prt][tsk][mrk][mrk+"_mean"]:.5}{"": <3}\t{qom_dict[prt][tsk][mrk][mrk+"_std"]:.5}')
            except(TypeError):
                continue
        print('\n')
# Out:
# P1
#
#
# task1		Mean		Std
#
# Head       	0.45051   	0.45974
# Back       	0.13679   	0.28581
# L_Shoulder 	0.15523   	0.31458
# R_Shoulder 	0.15312   	0.28359
# L_Elbow    	0.1867   	0.21482
# L_Hand     	0.32436   	0.395
# R_Elbow    	0.19038   	0.20397
# R_Hand     	0.3464   	0.30123
# Sustain_Foot 	0.11622   	0.31845
#
#
#
# task2		Mean		Std
#
# Head       	0.31413   	0.36475
# Back       	0.12927   	0.27448
# L_Shoulder 	0.13407   	0.25807
# R_Shoulder 	0.16899   	0.36091
# L_Elbow    	0.1673   	0.15684
# L_Hand     	0.33715   	0.32351
# R_Elbow    	0.29096   	0.61921
# R_Hand     	0.54638   	0.7121
# Sustain_Foot 	0.11295   	0.28012
#
#
#
# task3		Mean		Std
#
# Head       	0.27544   	0.22343
# Back       	0.072121   	0.053685
# L_Shoulder 	0.085911   	0.068995
# R_Shoulder 	0.0949   	0.075911
# L_Elbow    	0.15185   	0.16552
# L_Hand     	0.37045   	0.51037
# R_Elbow    	0.20713   	0.15292
# R_Hand     	0.50292   	0.41067
# Sustain_Foot 	0.21573   	0.48789
#
#
#
# ...

# %% [markdown]
# # Mean across participants (pr task)

# %%
# Making a new dataframe for task means
qom_case2_avg = pd.DataFrame(index=np.arange(1,13))
qom_case3_avg = pd.DataFrame(index=np.arange(1,13))
qom_case2_avg.index.name = qom_case3_avg.index.name = 'Task'

# Grabbing means pr participant for case 2 and 3
for i, prt in enumerate(qom_case2_plot):
    qom_case2_avg[f'P{i+1}'] = qom_case2_plot[i]
for i, prt in enumerate(qom_case3_plot):
    qom_case3_avg[f'P{i+1}'] = qom_case3_plot[i]
    
# Adding column with Means
qom_case2_avg['task_mean'] = qom_case2_avg.mean(axis=1)  
qom_case3_avg['task_mean'] = qom_case3_avg.mean(axis=1)

# %%
qom_case2_avg
# Out:
#             P1        P2        P3        P4  task_mean
# Task
# 1     0.201151  0.151530  0.161552  0.274526   0.197190
# 2     0.235885  0.159982  0.219775  0.170830   0.196618
# 3     0.212626  0.177301  0.260062  0.252951   0.225735
# 4     0.402073  0.286667  0.276809  0.297449   0.315750
# 5     0.131425  0.271252  0.199182  0.134255   0.184029
# 6     0.432858  0.295533  0.381410  0.194885   0.326171
# 7     0.223019  0.188463  0.192443  0.120583   0.181127
# 8     0.454090  0.172391  0.260180  0.188427   0.268772
# 9     0.296937  0.122828  0.092048  0.103928   0.153935
# 10    0.443893  0.164863  0.202677  0.189296   0.250182
# 11    0.153959  0.269043  0.238484  0.197891   0.214844
# 12    0.367755  0.155553  0.332967  0.215046   0.267830

# %%
qom_case3_avg
# Out:
#             P1        P2        P3        P4  task_mean
# Task
# 1     0.450514  0.152893  0.137297  0.226065   0.241692
# 2     0.314133  0.317073  0.198277  0.143974   0.243364
# 3     0.275444  0.262395  0.239198  0.167782   0.236205
# 4     0.415693  0.322162  0.200163  0.153531   0.272887
# 5     0.144876  0.421243  0.114327  0.109465   0.197478
# 6     0.378329  0.414342  0.203771  0.162741   0.289796
# 7     0.194856  0.449977  0.133593  0.102326   0.220188
# 8     0.470803  0.213350  0.218807  0.131297   0.258564
# 9     0.237395  0.291535  0.080987  0.123515   0.183358
# 10    0.349103  0.364128  0.191034  0.165269   0.267383
# 11    0.227294  0.351445  0.177697  0.138899   0.223834
# 12    0.610230  0.263722  0.258931  0.154875   0.321940

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16,6))

fig.suptitle('Average Quantity of Motion', fontsize=26)

rects1 = ax.bar(x - width/2, qom_case2_avg['task_mean'], width, label='Body')
rects2 = ax.bar(x + width/2, qom_case3_avg['task_mean'], width, label='Head')

ax.set_ylabel('QoM', fontsize=18)

# Border between Impro and Scales
ax.axvline(x=3.5, ls=':', lw=2, c='r', alpha=0.5)

ax.bar_label(rects1, label_type='edge', fmt='%.3f')
ax.bar_label(rects2, label_type='edge', fmt='%.3f')

ax.set_xticks(x, labels)

plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

ax.legend(fontsize=15)

plt.tight_layout()
plt.savefig("./plots/qom_avg.pdf")
plt.plot()
# Out:
# []

# %% [markdown]
# ## Exporting QoM plot data

# %%
import joblib

folder = './plot_data/'

# %%
joblib.dump(labels, folder+'labels')

joblib.dump(qom_case1_plot, folder+'qom_case1_plot')
joblib.dump(qom_case2_plot, folder+'qom_case2_plot')
joblib.dump(qom_case3_plot, folder+'qom_case3_plot')

joblib.dump(qom_case2_avg['task_mean'], folder+'task_means/qom_body')
joblib.dump(qom_case3_avg['task_mean'], folder+'task_means/qom_head')
# Out:
# ['./plot_data/task_means/qom_head']
